# %% [markdown]
# # NB2k — AI Counter-Generation: Gemini 3 Flash (via OpenRouter)
#
# The sixth and final generator. It closes the corpus: every card no earlier generator has salvaged,
# plus every card nobody has touched.
#
# **Input:** `fact_cards.parquet` + all six prior outputs.
# **Output:** `aig_gemini.parquet`.
#
# ## Where the corpus stands
#
# 3,056 of 3,500 cards have a passing AI article (deepseek 878, sonnet 739, qwen 622, gpt 437,
# opus 380). What's left is **444 cards** — 423 never touched plus 21 rejects GPT couldn't salvage —
# and I need 444 successes from them.
#
# That arithmetic is impossible in one pass: 444 from 444 would require a 100% gate rate, and my best
# generator so far (GPT-5 Mini) ran 95.4%. So I expect ~422 here and roughly 22 rejects, which a cheap
# salvage round then mops up. That's the relay doing what it's designed to do, not a failure.
#
# ## Same efficiency-tier logic
#
# Flash, not Pro — for the same reason I chose Sonnet over Opus and GPT-5 Mini over GPT-5. Opus is the
# stronger model and failed **90/470** where Sonnet failed **34/470**; the reject analysis showed why —
# entity coverage was fine (93%) but number coverage collapsed to 30%, because the more capable model
# renders "37 قتيلاً" as "عشرات القتلى". Counter-generation rewards literal carry-over of the card's
# facts, not editorial polish. The pattern has now held twice, so I'm applying it a third time.
#
# ## Reasoning: resolved automatically
#
# GPT-5 Mini turned out to *require* reasoning ("Reasoning is mandatory for this endpoint and cannot
# be disabled"), which cost me a run to discover. Gemini 3 Flash may or may not allow disabling it, so
# the smoke test below tries `enabled: false` first and falls back to `effort: low` on that exact
# error — no second run needed either way.

# %% [markdown]
# ## Setup, secrets, config

# %%
# !pip -q install openai >/dev/null 2>&1

import pandas as pd, numpy as np, json, re, os, time, random, glob
from openai import OpenAI
from kaggle_secrets import UserSecretsClient

# OpenRouter is OpenAI-API-compatible. The secret MUST be attached to THIS notebook
# (Add-ons -> Secrets). A fresh notebook does not inherit secrets automatically.
API_KEY = UserSecretsClient().get_secret('OPENROUTER_API_KEY')
client   = OpenAI(api_key=API_KEY, base_url='https://openrouter.ai/api/v1',
                  timeout=120.0, max_retries=0)   # 120s hard cap; I do my own retries

MODEL_NAME   = 'google/gemini-3-flash-preview'   # efficiency tier on purpose
GENERATOR_ID = 'gemini'
QUOTA        = 444                   # everything still missing; a salvage round will finish the last few
CARDS_PATH   = '/kaggle/input/notebooks/bahaaqassem/nb2c-build-fact-cards/fact_cards.parquet'
OUT_DIR      = '/kaggle/working'

# Every prior generator's output. I read these to (a) skip cards already processed and
# (b) pick up rejects nobody has salvaged yet. IMPORTANT: aigt-aig-qwen must hold the FINAL
# 637-row Qwen file — an earlier run read a stale 529-row copy and duplicated 2 cards.
PRIOR_OUTPUTS = [
    '/kaggle/input/notebooks/bahaaqassem/nb2d-generate-deepseek/aig_deepseek.parquet',
    '/kaggle/input/datasets/bahaaqassem/aig-qwen/aig_qwen.parquet',
    '/kaggle/input/notebooks/bahaaqassem/nb2f-generate-sonnet/aig_sonnet.parquet',
    '/kaggle/input/notebooks/bahaaqassem/nb2g-generate-opus/aig_opus.parquet',
    '/kaggle/input/notebooks/bahaaqassem/nb2h-retry-rejects/aig_sonnet_retry.parquet',
    '/kaggle/input/notebooks/bahaaqassem/nb2e-generate-gpt/aig_gpt.parquet',
]

RESUME_PATH  = None          # set to a partial aig_gemini.parquet to resume after a timeout
PILOT_N      = 30
PILOT_ONLY   = False          # True = 30-article pilot only. Set False for the production run.

PRICE_IN, PRICE_OUT = 0.50, 3.00     # Gemini 3 Flash $/1M tokens (OpenRouter), for cost projection

def find_parquet(preferred, *keywords):
    if os.path.exists(preferred):
        return preferred
    for kw in keywords:
        hits = [p for p in glob.glob('/kaggle/input/**/*.parquet', recursive=True) if kw in p]
        if hits:
            print(f'(resolved {kw} -> {hits[0]})')
            return hits[0]
    print('AVAILABLE /kaggle/input parquet files:')
    for p in glob.glob('/kaggle/input/**/*.parquet', recursive=True):
        print('   ', p)
    raise FileNotFoundError(f'could not find {preferred} (looked for {keywords})')

CARDS_PATH = find_parquet(CARDS_PATH, 'fact_cards', 'fact-cards')
cards = pd.read_parquet(CARDS_PATH)
print('cards:', cards.shape)
# Out:
# cards: (3500, 16)

# %% [markdown]
# ## Work list — carry-over first, then a sequential draw
#
# One ordered list (seeded shuffle, identical in every notebook). I skip every card any prior
# generator already processed, and I put the **unsalvaged rejects at the front** so they get tried
# early rather than after 400 fresh cards. Then I generate down the list until I've banked QUOTA
# successes; rejects don't count, so they simply flow on to Gemini.
#
# `failed - succeeded` is what makes the relay self-correcting across notebooks — DeepSeek's original
# 22 rejects don't appear here at all, because Qwen rescued every one of them.

# %%
ordered = cards.sample(frac=1.0, random_state=42).reset_index(drop=True)

processed, succeeded, failed = set(), set(), set()
for path in PRIOR_OUTPUTS:
    if not os.path.exists(path):
        kw = os.path.basename(path).replace('.parquet', '')
        hits = [p for p in glob.glob('/kaggle/input/**/*.parquet', recursive=True)
                if kw in p or kw.replace('_', '-') in p]
        path = hits[0] if hits else path
    if os.path.exists(path):
        prev = pd.read_parquet(path)
        processed |= set(prev['source_pair_id'])
        succeeded |= set(prev.loc[prev['gate_passed'], 'source_pair_id'])
        failed    |= set(prev.loc[~prev['gate_passed'], 'source_pair_id'])
        print(f'{os.path.basename(path):<28} {len(prev):4d} rows, '
              f'{int((~prev["gate_passed"]).sum()):3d} rejects')
    else:
        print(f'WARNING: prior output not found: {path}')

carry_over  = failed - succeeded                       # failed somewhere, rescued nowhere
carry_cards = ordered[ordered['pair_id'].isin(carry_over)]
fresh_cards = ordered[~ordered['pair_id'].isin(processed)]

my_cards = (pd.concat([carry_cards, fresh_cards])       # carry-over FIRST
              .drop_duplicates('pair_id')
              .reset_index(drop=True))

print(f'\ncarry-over (unsalvaged): {len(carry_cards)}')
print(f'fresh (untouched)      : {len(fresh_cards)}')
print(f'work list              : {len(my_cards)} cards | quota {QUOTA} successes')
print('sample ids:', my_cards['pair_id'].head(3).tolist())
# Out:
# aig_deepseek.parquet          900 rows,  22 rejects
# aig_qwen.parquet              529 rows,  11 rejects
# aig_sonnet.parquet            470 rows,  34 rejects
# aig_opus.parquet              470 rows,  90 rejects
# aig_sonnet_retry.parquet      485 rows,  81 rejects
# aig_gpt.parquet               461 rows,  21 rejects
#
# carry-over (unsalvaged): 21
# fresh (untouched)      : 423
# work list              : 444 cards | quota 444 successes
# sample ids: ['HA_03178', 'HA_01134', 'HA_01264']

# %% [markdown]
# ## Prompt (mirror rule + explicit length band + no-formatting)
#
# Conditional requirements fire only when the source actually has that element (mirror rule). I state
# an explicit length band and forbid markdown so the raw output already matches the human corpus
# (single paragraph, no `**`).

# %%
STYLE_HINTS = [
    'ابدأ بفقرة استهلالية تلخّص الحدث',
    'اذكر خلفية موجزة للسياق',
    'أورد ردود فعل الأطراف المعنية',
    'اختم بما هو متوقّع أو منتظر',
    'استخدم بنية الهرم المقلوب',
    'انسب المعلومات إلى مصادرها',
]

SYSTEM_PROMPT = (
    'أنت صحفي محترف يكتب تقارير إخبارية بالعربية الفصحى لصالح غرفة أخبار محترمة. '
    'تكتب بأسلوب صحفي رصين ودقيق، وتلتزم بالحقائق المعطاة دون إضافة معلومات من خارجها.'
)

# ---- number cleanup so prompt & gate agree (dual-calendar months, junk single digits) ----
MONTH_GROUPS = [
    {'يناير','كانون الثاني'}, {'فبراير','شباط'}, {'مارس','آذار'},
    {'أبريل','نيسان'}, {'مايو','أيار'}, {'يونيو','حزيران'},
    {'يوليو','تموز'}, {'أغسطس','آب'}, {'سبتمبر','أيلول'},
    {'أكتوبر','تشرين الأول'}, {'نوفمبر','تشرين الثاني'}, {'ديسمبر','كانون الأول'},
]
AMBIG = {'كانون': 0, 'تشرين': 9}

def month_group(item):
    for i, g in enumerate(MONTH_GROUPS):
        if any(m in item for m in g):
            return i
    for k, i in AMBIG.items():
        if k in item:
            return i
    return None

def clean_numbers(nums, cap=6):
    seen, out = set(), []
    for n in nums:
        n = n.strip()
        if re.fullmatch(r'[٠-٩0-9]', n):     # bare single digit = list marker
            continue
        g = month_group(n)
        if g is not None:
            if g in seen:
                continue
            seen.add(g)
        out.append(n)
    return out[:cap]

def build_prompt(card):
    ents   = json.loads(card['entities_for_prompt'])
    facts  = json.loads(card['fact_points'])
    target = int(card['target_words'])

    parts = [
        'اكتب تقريراً إخبارياً بالعربية الفصحى عن الموضوع التالي.',
        '',
        f'الموضوع: {card["topic_core"]}',
        '',
        'الكيانات التي يجب أن يذكرها التقرير:',
        '، '.join(ents),
        '',
        'الحقائق الأساسية التي يجب تغطيتها:',
    ]
    for f in facts:
        parts.append(f'- {f}')

    if card['has_numbers']:
        nums = clean_numbers(json.loads(card['numbers_dates']))
        if nums:
            # slight emphasis: Qwen tends to drop numbers; ask once, clearly, without over-pushing
            parts += ['', 'احرص على ذكر هذه الأرقام والتواريخ كما هي: ' + '، '.join(nums)]
    if card['has_agencies']:
        ags = json.loads(card['source_agencies'])
        parts += ['', 'انسب المعلومات إلى: ' + '، '.join(ags)]
    if card['has_quotes']:
        parts += ['', 'أدرج تصريحات منسوبة للأطراف المعنية، بصياغتك أنت.']

    hints = random.sample(STYLE_HINTS, k=random.choice([3, 4]))
    parts += ['', 'إرشادات التحرير:'] + [f'- {h}' for h in hints]
    parts += ['',
              f'الطول: لا يقل التقرير عن {target} كلمة ولا يزيد عن {int(target*1.12)} كلمة. '
              f'اكتب تقريراً مكتملاً ضمن هذا النطاق.',
              '',
              'اكتب نص التقرير مباشرة: دون عنوان، ودون أي تنسيق (لا نجوم ** ولا رموز تنسيق)، '
              'ودون مقدمة أو تعليق منك.']
    return '\n'.join(parts)

# %% [markdown]
# ## Formatting normalization (shared by both classes)
#
# The model tends to wrap articles in a bold headline and split them into paragraphs; my human
# corpus has none of that. I strip formatting artifacts and collapse newlines so the raw AI output
# already matches the human single-paragraph shape. NB3 applies the identical function to both
# classes, keeping the treatment symmetric.

# %%
def normalize_format(text):
    t = str(text)
    t = re.sub(r'<think>.*?</think>', '', t, flags=re.S)   # Qwen: strip any reasoning trace
    t = re.sub(r'\*\*(.+?)\*\*', r'\1', t)               # bold
    t = re.sub(r'__(.+?)__', r'\1', t)
    t = re.sub(r'(?<!\w)\*(.+?)\*(?!\w)', r'\1', t)      # italic
    t = re.sub(r'^#{1,6}\s*', '', t, flags=re.M)          # headings
    t = re.sub(r'^\s*[-–—>]\s+', '', t, flags=re.M)   # bullets / quotes
    t = re.sub(r'^\s*[-*_]{3,}\s*$', '', t, flags=re.M)   # rules
    t = re.sub(r'\n+', ' ', t)                            # human text has no newlines
    t = re.sub(r'\s{2,}', ' ', t)
    return t.strip()

# %% [markdown]
# ## Decoding parameters and generation
#
# Gemini accepts `temperature` alongside `top_p` and the penalties, so per-card decoding variation is
# available here — same ranges my DeepSeek, Qwen and GPT notebooks used.
#
# `REASONING` starts at `{'enabled': False}` and the smoke test rewrites it if this endpoint refuses
# to run without reasoning. Either way I never want the reasoning trace in the article text: it's
# billed as output and would eat into `max_tokens`, silently truncating long reports — the trap
# Sonnet 5's adaptive thinking set for me.

# %%
# Settled by the smoke test below: start by asking for no reasoning at all (cheapest), and fall
# back to minimal reasoning if this endpoint mandates it, the way GPT-5 Mini did.
REASONING = {'enabled': False}

def sample_params():
    return {
        'temperature':       round(random.uniform(0.8, 1.1), 3),
        'top_p':             0.95,
        'frequency_penalty': round(random.uniform(0.2, 0.5), 3),
        'presence_penalty':  0.1,
    }

def _call(messages, params, max_tokens, max_retries=5):
    # Empty completions are NOT network errors, so I retry them immediately (no backoff);
    # only real network/API errors get a short capped wait.
    last_err = None
    for attempt in range(max_retries):
        try:
            resp = client.chat.completions.create(
                model=MODEL_NAME, messages=messages, max_tokens=max_tokens,
                timeout=90.0,
                extra_body={'reasoning': REASONING},
                **params)
            content = resp.choices[0].message.content
            if not content or not content.strip():
                last_err = RuntimeError('empty completion')
                continue
            return content.strip(), resp.usage
        except Exception as e:
            last_err = e
            if attempt == max_retries - 1:
                raise
            time.sleep(min(2 ** attempt, 8))
    raise last_err

def generate_article(card, params):
    prompt = build_prompt(card)
    target = int(card['target_words'])
    msgs = [{'role': 'system', 'content': SYSTEM_PROMPT},
            {'role': 'user',   'content': prompt}]
    text, usage = _call(msgs, params, int(target * 4.5) + 800)
    text = normalize_format(text)
    tin, tout = usage.prompt_tokens, usage.completion_tokens

    n = len(text.split())
    if n < target * 0.88:
        need = int((target - n) * 0.9)          # measured, to avoid overshoot
        msgs2 = msgs + [{'role': 'assistant', 'content': text},
                        {'role': 'user',
                         'content': f'أضف نحو {need} كلمة فقط لإكمال التقرير بنفس الأسلوب، '
                                    f'دون تكرار ما ورد ودون تنسيق. اكتب التتمة فقط.'}]
        try:
            ext, usage2 = _call(msgs2, params, int(need * 4.5) + 400)
            text = normalize_format(text + ' ' + normalize_format(ext))
            tin += usage2.prompt_tokens; tout += usage2.completion_tokens
        except Exception:
            pass
    return text, tin, tout

# %% [markdown]
# ## Acceptance gate (fuzzy, prefix-tolerant, mirror-rule aware)
#
# Accept only if the article anchors to the same event: weighted coverage >= 80% AND entity coverage
# >= 65% (hard floor). Only elements the source actually had are scored. Matching normalizes clitics,
# `ال`, diacritics, alef/ya/ta-marbuta and Arabic-Indic vs Western digits; a month is satisfied by
# either calendar name.

# %%
_AR_DIGITS = str.maketrans('٠١٢٣٤٥٦٧٨٩',
                           '0123456789')

def _norm(s):
    s = re.sub(r'[\u064B-\u0652]', '', s)                # diacritics
    s = s.translate(_AR_DIGITS)
    return (s.replace('أ','ا').replace('إ','ا').replace('آ','ا')
             .replace('ة','ه').replace('ى','ي'))

def _norm_entity(e):
    e = _norm(e)
    e = re.sub(r'^[وفبكل]?ال', '', e)
    e = re.sub(r'^لل', '', e)
    e = re.sub(r'^[وفبكل](?=.{3,})', '', e)
    return e.strip()

def _present(item, tn, is_entity=True):
    n = _norm_entity(item) if is_entity else _norm(item)
    return len(n) >= 2 and n in tn

def _number_present(item, tn):
    g = month_group(item)
    if g is not None:
        names = MONTH_GROUPS[g] | {k for k, v in AMBIG.items() if v == g}
        return any(_norm(m) in tn for m in names)
    return _present(item, tn, is_entity=False)

def acceptance_gate(article, card, W_ENT=3, W_NUM=2, W_AG=1):
    tn = _norm(article)
    scores, weights, detail = [], [], {}

    ents = json.loads(card['entities_for_prompt'])
    if ents:
        hit = sum(_present(e, tn) for e in ents)
        ent_cov = hit / len(ents)
        detail['entities'] = f'{hit}/{len(ents)}'
        scores.append(ent_cov); weights.append(W_ENT)
    else:
        ent_cov = 1.0
        detail['entities'] = 'none'

    if card['has_numbers']:
        nums = clean_numbers(json.loads(card['numbers_dates']))
        if nums:
            hit = sum(_number_present(n, tn) for n in nums)
            c = hit / len(nums); detail['numbers'] = f'{hit}/{len(nums)}'
            scores.append(c); weights.append(W_NUM)
    if card['has_agencies']:
        ags = json.loads(card['source_agencies'])
        hit = sum(_present(a, tn, False) for a in ags)
        c = hit / max(len(ags), 1); detail['agencies'] = f'{hit}/{len(ags)}'
        scores.append(c); weights.append(W_AG)

    weighted = sum(s * w for s, w in zip(scores, weights)) / max(sum(weights), 1)
    passed = (weighted >= 0.80) and (ent_cov >= 0.65)
    return {'passed': passed, 'weighted': round(weighted, 3),
            'entity_cov': round(ent_cov, 3), 'detail': detail}

def length_ok(article, target, tol=0.15):
    n = len(article.split())
    return abs(n - target) / target <= tol, n

# %% [markdown]
# ## Smoke test — one live call, with automatic reasoning fallback
#
# Cheap insurance that has now paid for itself three times: Sonnet and Opus each errored on all 470
# batch requests over deprecated sampling params, and GPT-5 Mini refused `reasoning: enabled=false`
# outright. Each of those cost a run to discover.
#
# So this cell resolves the question itself. It tries `enabled: false` (no reasoning tokens, cheapest);
# if the endpoint answers that reasoning is mandatory, it rewrites `REASONING` to `effort: low` +
# `exclude: true` and tries again. Whatever survives is what the production loop uses.

# %%
_c = my_cards.iloc[0]

def _smoke(reasoning_cfg):
    global REASONING
    REASONING = reasoning_cfg
    return generate_article(_c, sample_params())

SMOKE_OK = False
for _cfg in [{'enabled': False},                       # preferred: no reasoning tokens at all
             {'effort': 'low', 'exclude': True}]:      # fallback: minimal, not returned
    try:
        _t, _ti, _to = _smoke(_cfg)
        print('SMOKE TEST OK —', MODEL_NAME, '| reasoning:', REASONING)
        print(f'  tokens: {_ti} in / {_to} out | words: {len(_t.split())} (target {int(_c["target_words"])})')
        print('  md left:', '**' in _t, '| newlines left:', chr(10) in _t)
        print('  sample:', _t[:150].replace(chr(10), ' '), '...')
        SMOKE_OK = True
        break
    except Exception as _e:
        _msg = str(_e)
        print(f'  reasoning={_cfg} rejected: {type(_e).__name__}: {_msg[:160]}')
        if 'reasoning' not in _msg.lower():
            break                                       # not a reasoning problem — don't mask it

if not SMOKE_OK:
    print('SMOKE TEST FAILED — fix params before the production run. REASONING left at', REASONING)
# Out:
# SMOKE TEST OK — google/gemini-3-flash-preview | reasoning: {'enabled': False}
#   tokens: 661 in / 2941 out | words: 1441 (target 1284)
#   md left: False | newlines left: False
#   sample: سيطرت حالة من الغليان الأمني والتصعيد العسكري الميداني على الأراضي الفلسطينية المحتلة، وسط موجة من الاغتيالات وعمليات القصف الممنهج التي تنفذها قوات ا ...

# %% [markdown]
# ## Phase A — pilot (30 cards, synchronous)
#
# Generates 30, prints each live, saves after each, reports gate/length/cost and a formatting-artifact
# check. Nothing here is destructive; I read the results before spending on the rest.

# %%
# Phase A (pilot): runs ONLY when PILOT_ONLY is True.
# In production/resume mode it is skipped entirely — no wasted pilot regeneration.
PILOT_CKPT = f'{OUT_DIR}/pilot_{GENERATOR_ID}.parquet'
p = None

def _run_pilot():

    pilot = my_cards.head(PILOT_N)
    rows, t0 = [], time.time()
    tok_in = tok_out = 0

    print(f'--- pilot: {PILOT_N} articles ---', flush=True)
    for i, card in pilot.iterrows():
        a0 = time.time()
        try:
            params = sample_params()
            text, tin, tout = generate_article(card, params)
            gate = acceptance_gate(text, card)
            lok, nwords = length_ok(text, int(card['target_words']))
            tok_in += tin; tok_out += tout
            rows.append({'pair_id': card['pair_id'], 'passed': gate['passed'],
                         'weighted': gate['weighted'], 'entity_cov': gate['entity_cov'],
                         'len_ok': lok, 'words': nwords, 'target': int(card['target_words']),
                         'detail': str(gate['detail']), 'text': text})
            pd.DataFrame(rows).to_parquet(PILOT_CKPT, index=False)          # save after every article
            flag = 'OK ' if (gate['passed'] and lok) else 'BAD'
            print(f'[{len(rows):2d}/{PILOT_N}] {flag} {card["pair_id"]} | '
                  f'cov={gate["weighted"]:.0%} ent={gate["entity_cov"]:.0%} '
                  f'| {nwords}w/{int(card["target_words"])}w ({nwords/int(card["target_words"]):.2f}) '
                  f'| md={chr(34)+chr(34) in text} | {time.time()-a0:.0f}s | {gate["detail"]}',
                  flush=True)
        except Exception as e:
            print(f'[{len(rows):2d}/{PILOT_N}] ERR {card["pair_id"]}: {type(e).__name__}: {str(e)[:120]}',
                  flush=True)

    p = pd.DataFrame(rows)
    print(f'\n=== pilot summary ===')
    print(f'generated  : {len(p)}/{PILOT_N} in {time.time()-t0:.0f}s')
    print(f'gate pass  : {p["passed"].sum()}/{len(p)} ({100*p["passed"].mean():.0f}%)')
    print(f'length ok  : {p["len_ok"].sum()}/{len(p)} ({100*p["len_ok"].mean():.0f}%)')
    print(f'entity cov : mean {p["entity_cov"].mean():.0%} | min {p["entity_cov"].min():.0%}')
    print(f'weighted   : mean {p["weighted"].mean():.0%}')
    print(f'words/target: mean {(p["words"]/p["target"]).mean():.2f}')
    cost = tok_in/1e6*PRICE_IN + tok_out/1e6*PRICE_OUT
    print(f'cost       : ${cost:.3f} | projected {N_TARGET}: ${cost/max(len(p),1)*N_TARGET:.2f}')

    n_md = int(p['text'].str.contains('**', regex=False).sum())
    n_nl = int(p['text'].str.contains(chr(10), regex=False).sum())
    print(f'\nmarkdown left: {n_md} | newlines left: {n_nl}   (both must be 0)')
    if n_md or n_nl:
        print('!! formatting artifacts present — do NOT run production until fixed')
    return p

if PILOT_ONLY:
    p = _run_pilot()
else:
    print('production/resume mode — pilot skipped, going straight to Phase B')
# Out:
# production/resume mode — pilot skipped, going straight to Phase B

# %%
# read one full article + list any failures (pilot mode only)
if p is not None and len(p):
    best = p.loc[p['weighted'].idxmax()]
    print('='*70); print('BEST', best['pair_id'], best['detail'], f"{best['words']}w/{best['target']}w")
    print('='*70); print(best['text'][:1200])
    fails = p[~p['passed']]
    print(f'\nfailed: {len(fails)}')
    for _, f in fails.iterrows():
        print(f"  {f['pair_id']}: w={f['weighted']:.0%} ent={f['entity_cov']:.0%} {f['detail']}")

# %% [markdown]
# ## Phase B — production (draw until QUOTA successes)
#
# Saves after every single article, so a Kaggle timeout costs me nothing but time: set `RESUME_PATH`
# to the partial parquet and the run picks up its banked successes and carries on. The loop stops the
# moment `n_success` hits QUOTA — rejects never count toward it.

# %%
def make_record(card, text, params, gate, nwords, lok, attempt, error=''):
    return {
        'id': f'AI_{GENERATOR_ID}_{card["pair_id"]}',
        'text': text, 'label': 'ai', 'generator': GENERATOR_ID,
        'source_pair_id': card['pair_id'],
        'temperature': params.get('temperature', 0), 'top_p': params.get('top_p', 0),
        'frequency_penalty': params.get('frequency_penalty', 0),
        'presence_penalty': params.get('presence_penalty', 0),
        'target_words': int(card['target_words']), 'actual_words': nwords,
        'entities_injected': card['entities_for_prompt'],
        'coverage_weighted': gate.get('weighted', 0), 'coverage_entities': gate.get('entity_cov', 0),
        'gate_passed': bool(gate.get('passed', False)), 'length_ok': bool(lok),
        'generation_attempts': attempt, 'error': error,
    }

# %%
CKPT         = f'{OUT_DIR}/aig_{GENERATOR_ID}.parquet'
MAX_ATTEMPTS = 2
# To RESUME after a timeout: upload the partial aig_qwen.parquet as a dataset and set the path.
RESUME_PATH  = '/kaggle/input/aigt-aig-qwen-partial/aig_qwen.parquet'  # set None for a fresh run

if not PILOT_ONLY:
    done_ids, records = set(), []
    for pth in [RESUME_PATH, CKPT]:
        if pth and os.path.exists(pth):
            prev = pd.read_parquet(pth)
            records = prev.to_dict('records'); done_ids = set(prev['source_pair_id'])
            print(f'resuming: {len(done_ids)} already done', flush=True)
            break

    # resume: count successes already banked, and skip every card already processed
    done_pairs = {r['source_pair_id'] for r in records}
    n_success  = sum(1 for r in records if r.get('gate_passed'))
    todo = my_cards[~my_cards['pair_id'].isin(done_pairs)].reset_index(drop=True)
    print(f'quota {QUOTA} successes | already banked {n_success} | work list {len(todo)} remaining',
          flush=True)

    t0 = time.time(); n_rej = n_err = 0; tin_tot = tout_tot = 0
    for i, card in todo.iterrows():
        if n_success >= QUOTA:                    # STOP when the quota of SUCCESSES is met
            print(f'quota reached: {n_success} successes — stopping draw', flush=True)
            break
        try:
            best_rec, params = None, {}
            for attempt in range(1, MAX_ATTEMPTS + 1):
                params = sample_params()
                text, tin, tout = generate_article(card, params)
                tin_tot += tin; tout_tot += tout
                gate = acceptance_gate(text, card)
                lok, nwords = length_ok(text, int(card['target_words']))
                rec = make_record(card, text, params, gate, nwords, lok, attempt)
                if best_rec is None or (rec['gate_passed'], rec['coverage_weighted']) > \
                                       (best_rec['gate_passed'], best_rec['coverage_weighted']):
                    best_rec = rec                 # keep the best attempt
                if gate['passed'] and lok:
                    break
            rec = best_rec
            if rec['gate_passed']:
                n_success += 1                     # only PASSING articles count toward the quota
            else:
                n_rej += 1
        except Exception as e:
            rec = make_record(card, '', {}, {}, 0, False, 0, f'{type(e).__name__}: {str(e)[:150]}')
            n_err += 1
            print(f'ERR {card["pair_id"]}: {rec["error"]}', flush=True)

        records.append(rec)
        pd.DataFrame(records).to_parquet(CKPT, index=False)          # SAVE AFTER EVERY ARTICLE

        done = len(records)
        status = 'ERR' if rec['error'] else ('OK ' if rec['gate_passed'] else 'BAD')
        rate = n_success / max(time.time() - t0, 1e-6)
        eta  = (QUOTA - n_success) / max(rate, 1e-6) / 60
        print(f'[proc {done:4d} | ok {n_success:3d}/{QUOTA}] {status} {card["pair_id"]} | '
              f'cov={rec["coverage_weighted"]:.0%} ent={rec["coverage_entities"]:.0%} '
              f'| {rec["actual_words"]}w/{rec["target_words"]}w | att={rec["generation_attempts"]} '
              f'| bad={n_rej} err={n_err} | ETA {eta:.0f}m', flush=True)

        if done % 10 == 0:
            cost = tin_tot/1e6*PRICE_IN + tout_tot/1e6*PRICE_OUT
            print(f'    >>> processed {done} | {n_success}/{QUOTA} successes | cost so far ${cost:.2f}',
                  flush=True)

    cost = tin_tot/1e6*PRICE_IN + tout_tot/1e6*PRICE_OUT
    if n_success < QUOTA:
        print(f'\n!! WORK LIST EXHAUSTED before quota: {n_success}/{QUOTA}. Need more cards.', flush=True)
    print(f'\nDONE {GENERATOR_ID} | successes={n_success}/{QUOTA} | rejects={n_rej} err={n_err} '
          f'| processed={len(records)} | total cost ${cost:.2f}', flush=True)
else:
    print('PILOT_ONLY is True — production skipped. Review the pilot, then set PILOT_ONLY = False.')
# Out:
# quota 444 successes | already banked 0 | work list 444 remaining
# [proc    1 | ok   1/444] OK  HA_03178 | cov=100% ent=100% | 1248w/1284w | att=1 | bad=0 err=0 | ETA 131m
# [proc    2 | ok   2/444] OK  HA_01134 | cov=98% ent=96% | 499w/522w | att=1 | bad=0 err=0 | ETA 96m
# [proc    3 | ok   3/444] OK  HA_01264 | cov=98% ent=96% | 547w/530w | att=1 | bad=0 err=0 | ETA 84m
# [proc    4 | ok   3/444] BAD HA_03182 | cov=67% ent=45% | 1422w/1074w | att=1 | bad=1 err=0 | ETA 170m
# [proc    5 | ok   4/444] OK  HA_03426 | cov=100% ent=100% | 1528w/1189w | att=1 | bad=1 err=0 | ETA 210m
# [proc    6 | ok   5/444] OK  HA_01590 | cov=100% ent=100% | 673w/608w | att=1 | bad=1 err=0 | ETA 180m
# [proc    7 | ok   6/444] OK  HA_02019 | cov=100% ent=100% | 526w/554w | att=1 | bad=1 err=0 | ETA 160m
# [proc    8 | ok   7/444] OK  HA_03166 | cov=98% ent=96% | 1569w/1694w | att=1 | bad=1 err=0 | ETA 161m
# [proc    9 | ok   8/444] OK  HA_02378 | cov=100% ent=100% | 1006w/764w | att=2 | bad=1 err=0 | ETA 166m
# [proc   10 | ok   9/444] OK  HA_00020 | cov=97% ent=93% | 407w/441w | att=1 | bad=1 err=0 | ETA 152m
#     >>> processed 10 | 9/444 successes | cost so far $0.08
# [proc   11 | ok  10/444] OK  HA_03144 | cov=100% ent=100% | 1710w/2499w | att=1 | bad=1 err=0 | ETA 179m
# [proc   12 | ok  11/444] OK  HA_00855 | cov=100% ent=100% | 438w/475w | att=1 | bad=1 err=0 | ETA 167m
# [proc   13 | ok  12/444] OK  HA_02779 | cov=100% ent=100% | 770w/785w | att=1 | bad=1 err=0 | ETA 159m
# [proc   14 | ok  13/444] OK  HA_03102 | cov=100% ent=100% | 1111w/1139w | att=1 | bad=1 err=0 | ETA 155m
# [proc   15 | ok  14/444] OK  HA_02082 | cov=100% ent=100% | 650w/577w | att=1 | bad=1 err=0 | ETA 148m
# [proc   16 | ok  15/444] OK  HA_03278 | cov=100% ent=100% | 1489w/1178w | att=1 | bad=1 err=0 | ETA 157m
# [proc   17 | ok  16/444] OK  HA_02521 | cov=100% ent=100% | 749w/700w | att=1 | bad=1 err=0 | ETA 152m
# [proc   18 | ok  17/444] OK  HA_02703 | cov=97% ent=96% | 819w/758w | att=1 | bad=1 err=0 | ETA 148m
# [proc   19 | ok  18/444] OK  HA_02914 | cov=97% ent=94% | 1302w/1378w | att=1 | bad=1 err=0 | ETA 147m
# [proc   20 | ok  19/444] OK  HA_01077 | cov=100% ent=100% | 488w/537w | att=1 | bad=1 err=0 | ETA 142m
#     >>> processed 20 | 19/444 successes | cost so far $0.17
# [proc   21 | ok  20/444] OK  HA_01841 | cov=100% ent=100% | 558w/586w | att=1 | bad=1 err=0 | ETA 137m
# [proc   22 | ok  21/444] OK  HA_01705 | cov=98% ent=97% | 600w/613w | att=1 | bad=1 err=0 | ETA 133m
# [proc   23 | ok  22/444] OK  HA_03436 | cov=100% ent=100% | 1125w/1121w | att=1 | bad=1 err=0 | ETA 133m
# [proc   24 | ok  23/444] OK  HA_00245 | cov=100% ent=100% | 417w/414w | att=1 | bad=1 err=0 | ETA 129m
# [proc   25 | ok  24/444] OK  HA_00784 | cov=100% ent=100% | 499w/504w | att=1 | bad=1 err=0 | ETA 125m
# [proc   26 | ok  25/444] OK  HA_01409 | cov=100% ent=100% | 583w/587w | att=1 | bad=1 err=0 | ETA 122m
# [proc   27 | ok  26/444] OK  HA_02537 | cov=100% ent=100% | 949w/800w | att=1 | bad=1 err=0 | ETA 124m
# [proc   28 | ok  27/444] OK  HA_00154 | cov=100% ent=100% | 407w/451w | att=2 | bad=1 err=0 | ETA 122m
# [proc   29 | ok  28/444] OK  HA_03009 | cov=100% ent=100% | 1392w/1241w | att=1 | bad=1 err=0 | ETA 123m
# [proc   30 | ok  29/444] OK  HA_01686 | cov=100% ent=100% | 584w/563w | att=1 | bad=1 err=0 | ETA 120m
#     >>> processed 30 | 29/444 successes | cost so far $0.22
# [proc   31 | ok  30/444] OK  HA_02901 | cov=98% ent=96% | 2409w/4425w | att=1 | bad=1 err=0 | ETA 131m
# [proc   32 | ok  31/444] OK  HA_00625 | cov=100% ent=100% | 391w/429w | att=1 | bad=1 err=0 | ETA 127m
# [proc   33 | ok  32/444] OK  HA_02733 | cov=98% ent=96% | 884w/761w | att=1 | bad=1 err=0 | ETA 128m
# [proc   34 | ok  33/444] OK  HA_03354 | cov=98% ent=96% | 901w/891w | att=1 | bad=1 err=0 | ETA 127m
# [proc   35 | ok  34/444] OK  HA_01346 | cov=96% ent=94% | 528w/536w | att=1 | bad=1 err=0 | ETA 124m
# [proc   36 | ok  35/444] OK  HA_00569 | cov=100% ent=100% | 456w/453w | att=1 | bad=1 err=0 | ETA 122m
# [proc   37 | ok  36/444] OK  HA_03419 | cov=89% ent=90% | 793w/901w | att=1 | bad=1 err=0 | ETA 120m
# [proc   38 | ok  37/444] OK  HA_01758 | cov=93% ent=86% | 611w/550w | att=1 | bad=1 err=0 | ETA 119m
# [proc   39 | ok  38/444] OK  HA_01816 | cov=100% ent=100% | 540w/588w | att=1 | bad=1 err=0 | ETA 117m
# [proc   40 | ok  39/444] OK  HA_02065 | cov=100% ent=100% | 522w/544w | att=1 | bad=1 err=0 | ETA 115m
#     >>> processed 40 | 39/444 successes | cost so far $0.29
# [proc   41 | ok  40/444] OK  HA_00127 | cov=91% ent=86% | 528w/465w | att=1 | bad=1 err=0 | ETA 113m
# [proc   42 | ok  41/444] OK  HA_03472 | cov=100% ent=100% | 1252w/1195w | att=1 | bad=1 err=0 | ETA 113m
# [proc   43 | ok  42/444] OK  HA_02006 | cov=100% ent=100% | 668w/589w | att=1 | bad=1 err=0 | ETA 112m
# [proc   44 | ok  43/444] OK  HA_02975 | cov=97% ent=93% | 1289w/1008w | att=1 | bad=1 err=0 | ETA 114m
# [proc   45 | ok  44/444] OK  HA_00980 | cov=100% ent=100% | 453w/488w | att=1 | bad=1 err=0 | ETA 112m
# [proc   46 | ok  45/444] OK  HA_03468 | cov=100% ent=100% | 1519w/1614w | att=1 | bad=1 err=0 | ETA 112m
# [proc   47 | ok  46/444] OK  HA_00190 | cov=100% ent=100% | 404w/444w | att=1 | bad=1 err=0 | ETA 111m
# [proc   48 | ok  47/444] OK  HA_01139 | cov=100% ent=100% | 485w/487w | att=1 | bad=1 err=0 | ETA 109m
# [proc   49 | ok  48/444] OK  HA_00992 | cov=100% ent=100% | 540w/537w | att=1 | bad=1 err=0 | ETA 108m
# [proc   50 | ok  49/444] OK  HA_00699 | cov=97% ent=96% | 457w/438w | att=1 | bad=1 err=0 | ETA 106m
#     >>> processed 50 | 49/444 successes | cost so far $0.35
# [proc   51 | ok  50/444] OK  HA_00606 | cov=100% ent=100% | 484w/456w | att=1 | bad=1 err=0 | ETA 105m
# [proc   52 | ok  51/444] OK  HA_00180 | cov=100% ent=100% | 472w/453w | att=1 | bad=1 err=0 | ETA 103m
# [proc   53 | ok  52/444] OK  HA_00301 | cov=100% ent=100% | 409w/447w | att=1 | bad=1 err=0 | ETA 102m
# [proc   54 | ok  53/444] OK  HA_02544 | cov=100% ent=100% | 736w/657w | att=1 | bad=1 err=0 | ETA 101m
# [proc   55 | ok  54/444] OK  HA_03322 | cov=100% ent=100% | 1120w/1147w | att=1 | bad=1 err=0 | ETA 101m
# [proc   56 | ok  55/444] OK  HA_01060 | cov=98% ent=96% | 454w/492w | att=1 | bad=1 err=0 | ETA 100m
# [proc   57 | ok  56/444] OK  HA_03346 | cov=100% ent=100% | 1845w/1929w | att=1 | bad=1 err=0 | ETA 101m
# [proc   58 | ok  57/444] OK  HA_03356 | cov=100% ent=100% | 1681w/1803w | att=1 | bad=1 err=0 | ETA 102m
# [proc   59 | ok  58/444] OK  HA_02565 | cov=100% ent=100% | 949w/878w | att=1 | bad=1 err=0 | ETA 102m
# [proc   60 | ok  59/444] OK  HA_01069 | cov=100% ent=100% | 475w/472w | att=1 | bad=1 err=0 | ETA 100m
#     >>> processed 60 | 59/444 successes | cost so far $0.41
# [proc   61 | ok  60/444] OK  HA_02524 | cov=100% ent=100% | 814w/719w | att=1 | bad=1 err=0 | ETA 100m
# [proc   62 | ok  61/444] OK  HA_02205 | cov=100% ent=100% | 964w/879w | att=1 | bad=1 err=0 | ETA 99m
# [proc   63 | ok  62/444] OK  HA_01243 | cov=98% ent=96% | 536w/509w | att=1 | bad=1 err=0 | ETA 98m
# [proc   64 | ok  63/444] OK  HA_00016 | cov=100% ent=100% | 382w/431w | att=1 | bad=1 err=0 | ETA 97m
# [proc   65 | ok  64/444] OK  HA_03120 | cov=100% ent=100% | 1131w/992w | att=1 | bad=1 err=0 | ETA 97m
# [proc   66 | ok  65/444] OK  HA_03475 | cov=100% ent=100% | 1368w/3010w | att=1 | bad=1 err=0 | ETA 100m
# [proc   67 | ok  66/444] OK  HA_00546 | cov=100% ent=100% | 496w/465w | att=1 | bad=1 err=0 | ETA 99m
# [proc   68 | ok  67/444] OK  HA_00658 | cov=100% ent=100% | 394w/423w | att=1 | bad=1 err=0 | ETA 98m
# [proc   69 | ok  68/444] OK  HA_03154 | cov=100% ent=100% | 2072w/2215w | att=1 | bad=1 err=0 | ETA 99m
# [proc   70 | ok  69/444] OK  HA_03067 | cov=100% ent=100% | 1017w/1026w | att=1 | bad=1 err=0 | ETA 100m
#     >>> processed 70 | 69/444 successes | cost so far $0.48
# [proc   71 | ok  70/444] OK  HA_03192 | cov=100% ent=100% | 1672w/1391w | att=1 | bad=1 err=0 | ETA 103m
# [proc   72 | ok  71/444] OK  HA_01504 | cov=100% ent=100% | 656w/561w | att=1 | bad=1 err=0 | ETA 103m
# [proc   73 | ok  72/444] OK  HA_00959 | cov=100% ent=100% | 476w/485w | att=1 | bad=1 err=0 | ETA 102m
# [proc   74 | ok  73/444] OK  HA_02926 | cov=98% ent=96% | 1029w/1153w | att=1 | bad=1 err=0 | ETA 102m
# [proc   75 | ok  74/444] OK  HA_02331 | cov=100% ent=100% | 837w/728w | att=1 | bad=1 err=0 | ETA 103m
# [proc   76 | ok  75/444] OK  HA_00797 | cov=95% ent=95% | 504w/521w | att=1 | bad=1 err=0 | ETA 102m
# [proc   77 | ok  76/444] OK  HA_00225 | cov=100% ent=100% | 372w/405w | att=1 | bad=1 err=0 | ETA 101m
# [proc   78 | ok  77/444] OK  HA_02074 | cov=100% ent=100% | 589w/548w | att=1 | bad=1 err=0 | ETA 100m
# [proc   79 | ok  78/444] OK  HA_01799 | cov=98% ent=96% | 552w/568w | att=1 | bad=1 err=0 | ETA 99m
# [proc   80 | ok  79/444] OK  HA_02485 | cov=100% ent=100% | 853w/700w | att=1 | bad=1 err=0 | ETA 99m
#     >>> processed 80 | 79/444 successes | cost so far $0.54
# [proc   81 | ok  80/444] OK  HA_03454 | cov=100% ent=100% | 1075w/1044w | att=1 | bad=1 err=0 | ETA 99m
# [proc   82 | ok  81/444] OK  HA_02277 | cov=100% ent=100% | 714w/696w | att=1 | bad=1 err=0 | ETA 98m
# [proc   83 | ok  82/444] OK  HA_02085 | cov=100% ent=100% | 609w/609w | att=1 | bad=1 err=0 | ETA 97m
# [proc   84 | ok  83/444] OK  HA_01693 | cov=100% ent=100% | 659w/624w | att=1 | bad=1 err=0 | ETA 97m
# [proc   85 | ok  84/444] OK  HA_02797 | cov=100% ent=100% | 857w/707w | att=1 | bad=1 err=0 | ETA 97m
# [proc   86 | ok  85/444] OK  HA_01045 | cov=100% ent=100% | 451w/467w | att=1 | bad=1 err=0 | ETA 96m
# [proc   87 | ok  86/444] OK  HA_00469 | cov=100% ent=100% | 422w/423w | att=1 | bad=1 err=0 | ETA 95m
# [proc   88 | ok  87/444] OK  HA_00954 | cov=100% ent=100% | 499w/501w | att=1 | bad=1 err=0 | ETA 94m
# [proc   89 | ok  88/444] OK  HA_03471 | cov=100% ent=100% | 1174w/979w | att=1 | bad=1 err=0 | ETA 96m
# [proc   90 | ok  89/444] OK  HA_02735 | cov=96% ent=92% | 1023w/877w | att=1 | bad=1 err=0 | ETA 97m
#     >>> processed 90 | 89/444 successes | cost so far $0.61
# [proc   91 | ok  90/444] OK  HA_03362 | cov=100% ent=100% | 1036w/1031w | att=1 | bad=1 err=0 | ETA 96m
# [proc   92 | ok  91/444] OK  HA_00639 | cov=100% ent=100% | 378w/416w | att=1 | bad=1 err=0 | ETA 96m
# [proc   93 | ok  92/444] OK  HA_03245 | cov=98% ent=96% | 1488w/1517w | att=1 | bad=1 err=0 | ETA 96m
# [proc   94 | ok  93/444] OK  HA_01218 | cov=100% ent=100% | 460w/471w | att=1 | bad=1 err=0 | ETA 95m
# [proc   95 | ok  94/444] OK  HA_01158 | cov=100% ent=100% | 553w/514w | att=1 | bad=1 err=0 | ETA 95m
# [proc   96 | ok  95/444] OK  HA_01415 | cov=100% ent=100% | 600w/573w | att=1 | bad=1 err=0 | ETA 95m
# [proc   97 | ok  96/444] OK  HA_03165 | cov=96% ent=92% | 2552w/2760w | att=2 | bad=1 err=0 | ETA 97m
# [proc   98 | ok  97/444] OK  HA_01527 | cov=92% ent=83% | 711w/632w | att=1 | bad=1 err=0 | ETA 97m
# [proc   99 | ok  98/444] OK  HA_03407 | cov=100% ent=100% | 1123w/1063w | att=1 | bad=1 err=0 | ETA 96m
# [proc  100 | ok  99/444] OK  HA_01300 | cov=100% ent=100% | 499w/506w | att=1 | bad=1 err=0 | ETA 96m
#     >>> processed 100 | 99/444 successes | cost so far $0.69
# [proc  101 | ok 100/444] OK  HA_03343 | cov=100% ent=100% | 1427w/1096w | att=1 | bad=1 err=0 | ETA 97m
# [proc  102 | ok 101/444] OK  HA_02848 | cov=100% ent=100% | 1958w/3017w | att=1 | bad=1 err=0 | ETA 99m
# [proc  103 | ok 102/444] OK  HA_01603 | cov=100% ent=100% | 582w/545w | att=1 | bad=1 err=0 | ETA 98m
# [proc  104 | ok 103/444] OK  HA_00160 | cov=100% ent=100% | 431w/415w | att=1 | bad=1 err=0 | ETA 98m
# [proc  105 | ok 104/444] OK  HA_01704 | cov=83% ent=100% | 550w/550w | att=1 | bad=1 err=0 | ETA 97m
# [proc  106 | ok 105/444] OK  HA_00956 | cov=100% ent=100% | 545w/540w | att=1 | bad=1 err=0 | ETA 96m
# [proc  107 | ok 106/444] OK  HA_02869 | cov=100% ent=100% | 1078w/955w | att=1 | bad=1 err=0 | ETA 96m
# [proc  108 | ok 107/444] OK  HA_03400 | cov=100% ent=100% | 1174w/939w | att=2 | bad=1 err=0 | ETA 96m
# [proc  109 | ok 108/444] OK  HA_00877 | cov=100% ent=100% | 465w/489w | att=1 | bad=1 err=0 | ETA 96m
# [proc  110 | ok 109/444] OK  HA_01919 | cov=100% ent=100% | 632w/600w | att=1 | bad=1 err=0 | ETA 95m
#     >>> processed 110 | 109/444 successes | cost so far $0.78
# [proc  111 | ok 110/444] OK  HA_02961 | cov=100% ent=100% | 1023w/1099w | att=1 | bad=1 err=0 | ETA 94m
# [proc  112 | ok 111/444] OK  HA_01884 | cov=100% ent=100% | 687w/608w | att=1 | bad=1 err=0 | ETA 94m
# [proc  113 | ok 112/444] OK  HA_02200 | cov=100% ent=100% | 970w/800w | att=1 | bad=1 err=0 | ETA 94m
# [proc  114 | ok 113/444] OK  HA_00098 | cov=100% ent=100% | 389w/438w | att=1 | bad=1 err=0 | ETA 93m
# [proc  115 | ok 114/444] OK  HA_03298 | cov=100% ent=100% | 1613w/1648w | att=1 | bad=1 err=0 | ETA 93m
# [proc  116 | ok 115/444] OK  HA_02557 | cov=100% ent=100% | 767w/671w | att=1 | bad=1 err=0 | ETA 93m
# [proc  117 | ok 116/444] OK  HA_00253 | cov=100% ent=100% | 445w/443w | att=1 | bad=1 err=0 | ETA 92m
# [proc  118 | ok 117/444] OK  HA_00103 | cov=92% ent=95% | 399w/417w | att=1 | bad=1 err=0 | ETA 91m
# [proc  119 | ok 118/444] OK  HA_01445 | cov=100% ent=100% | 644w/586w | att=1 | bad=1 err=0 | ETA 91m
# [proc  120 | ok 119/444] OK  HA_01443 | cov=100% ent=100% | 663w/620w | att=1 | bad=1 err=0 | ETA 90m
#     >>> processed 120 | 119/444 successes | cost so far $0.83
# [proc  121 | ok 120/444] OK  HA_01648 | cov=100% ent=100% | 568w/588w | att=1 | bad=1 err=0 | ETA 90m
# [proc  122 | ok 121/444] OK  HA_00586 | cov=100% ent=100% | 422w/430w | att=1 | bad=1 err=0 | ETA 89m
# [proc  123 | ok 122/444] OK  HA_00627 | cov=100% ent=100% | 394w/426w | att=1 | bad=1 err=0 | ETA 88m
# [proc  124 | ok 123/444] OK  HA_01696 | cov=100% ent=100% | 584w/552w | att=1 | bad=1 err=0 | ETA 87m
# [proc  125 | ok 124/444] OK  HA_02101 | cov=100% ent=100% | 850w/825w | att=1 | bad=1 err=0 | ETA 87m
# [proc  126 | ok 125/444] OK  HA_02199 | cov=100% ent=100% | 831w/689w | att=1 | bad=1 err=0 | ETA 87m
# [proc  127 | ok 126/444] OK  HA_00403 | cov=96% ent=95% | 423w/443w | att=1 | bad=1 err=0 | ETA 86m
# [proc  128 | ok 127/444] OK  HA_01154 | cov=96% ent=94% | 567w/514w | att=1 | bad=1 err=0 | ETA 86m
# [proc  129 | ok 128/444] OK  HA_02255 | cov=100% ent=100% | 750w/667w | att=1 | bad=1 err=0 | ETA 85m
# [proc  130 | ok 129/444] OK  HA_02863 | cov=100% ent=100% | 1059w/1075w | att=1 | bad=1 err=0 | ETA 85m
#     >>> processed 130 | 129/444 successes | cost so far $0.88
# [proc  131 | ok 130/444] OK  HA_01682 | cov=100% ent=100% | 671w/606w | att=1 | bad=1 err=0 | ETA 84m
# [proc  132 | ok 131/444] OK  HA_03170 | cov=100% ent=100% | 1979w/2393w | att=2 | bad=1 err=0 | ETA 86m
# [proc  133 | ok 132/444] OK  HA_02056 | cov=100% ent=100% | 551w/562w | att=1 | bad=1 err=0 | ETA 85m
# [proc  134 | ok 133/444] OK  HA_03062 | cov=100% ent=100% | 1826w/4115w | att=1 | bad=1 err=0 | ETA 87m
# [proc  135 | ok 134/444] OK  HA_03318 | cov=100% ent=100% | 1396w/1485w | att=1 | bad=1 err=0 | ETA 87m
# [proc  136 | ok 135/444] OK  HA_03108 | cov=100% ent=100% | 996w/1005w | att=1 | bad=1 err=0 | ETA 86m
# [proc  137 | ok 136/444] OK  HA_00452 | cov=100% ent=100% | 363w/401w | att=1 | bad=1 err=0 | ETA 85m
# [proc  138 | ok 137/444] OK  HA_02301 | cov=100% ent=100% | 841w/706w | att=1 | bad=1 err=0 | ETA 85m
# [proc  139 | ok 138/444] OK  HA_01327 | cov=100% ent=100% | 601w/526w | att=1 | bad=1 err=0 | ETA 85m
# [proc  140 | ok 139/444] OK  HA_02944 | cov=98% ent=97% | 1014w/920w | att=1 | bad=1 err=0 | ETA 85m
#     >>> processed 140 | 139/444 successes | cost so far $0.98
# [proc  141 | ok 140/444] OK  HA_02049 | cov=98% ent=96% | 714w/641w | att=1 | bad=1 err=0 | ETA 84m
# [proc  142 | ok 141/444] OK  HA_00880 | cov=100% ent=100% | 504w/536w | att=1 | bad=1 err=0 | ETA 83m
# [proc  143 | ok 142/444] OK  HA_03403 | cov=100% ent=100% | 1217w/1167w | att=1 | bad=1 err=0 | ETA 83m
# [proc  144 | ok 143/444] OK  HA_00623 | cov=100% ent=100% | 394w/409w | att=1 | bad=1 err=0 | ETA 83m
# [proc  145 | ok 144/444] OK  HA_02393 | cov=100% ent=100% | 904w/746w | att=2 | bad=1 err=0 | ETA 83m
# [proc  146 | ok 145/444] OK  HA_03236 | cov=100% ent=100% | 1218w/1221w | att=1 | bad=1 err=0 | ETA 82m
# [proc  147 | ok 146/444] OK  HA_01787 | cov=100% ent=100% | 614w/545w | att=1 | bad=1 err=0 | ETA 82m
# [proc  148 | ok 147/444] OK  HA_00262 | cov=100% ent=100% | 366w/406w | att=1 | bad=1 err=0 | ETA 81m
# [proc  149 | ok 148/444] OK  HA_01634 | cov=97% ent=96% | 708w/632w | att=1 | bad=1 err=0 | ETA 81m
# [proc  150 | ok 149/444] OK  HA_01438 | cov=100% ent=100% | 697w/619w | att=1 | bad=1 err=0 | ETA 81m
#     >>> processed 150 | 149/444 successes | cost so far $1.04
# [proc  151 | ok 150/444] OK  HA_02198 | cov=100% ent=100% | 818w/778w | att=1 | bad=1 err=0 | ETA 80m
# [proc  152 | ok 151/444] OK  HA_01969 | cov=98% ent=96% | 751w/617w | att=1 | bad=1 err=0 | ETA 80m
# [proc  153 | ok 152/444] OK  HA_02520 | cov=100% ent=100% | 1107w/809w | att=1 | bad=1 err=0 | ETA 81m
# [proc  154 | ok 153/444] OK  HA_01802 | cov=100% ent=100% | 709w/626w | att=1 | bad=1 err=0 | ETA 80m
# [proc  155 | ok 154/444] OK  HA_00640 | cov=100% ent=100% | 396w/414w | att=1 | bad=1 err=0 | ETA 79m
# [proc  156 | ok 155/444] OK  HA_03484 | cov=100% ent=100% | 1266w/1224w | att=1 | bad=1 err=0 | ETA 79m
# [proc  157 | ok 156/444] OK  HA_02385 | cov=100% ent=100% | 759w/669w | att=1 | bad=1 err=0 | ETA 79m
# [proc  158 | ok 157/444] OK  HA_02598 | cov=100% ent=100% | 791w/760w | att=1 | bad=1 err=0 | ETA 78m
# [proc  159 | ok 158/444] OK  HA_03301 | cov=98% ent=96% | 1204w/1037w | att=1 | bad=1 err=0 | ETA 79m
# [proc  160 | ok 159/444] OK  HA_01959 | cov=100% ent=100% | 820w/608w | att=1 | bad=1 err=0 | ETA 79m
#     >>> processed 160 | 159/444 successes | cost so far $1.11
# [proc  161 | ok 160/444] OK  HA_02976 | cov=88% ent=88% | 1123w/1011w | att=1 | bad=1 err=0 | ETA 78m
# [proc  162 | ok 161/444] OK  HA_00488 | cov=93% ent=89% | 366w/401w | att=1 | bad=1 err=0 | ETA 78m
# [proc  163 | ok 162/444] OK  HA_01843 | cov=100% ent=100% | 640w/617w | att=1 | bad=1 err=0 | ETA 77m
# [proc  164 | ok 163/444] OK  HA_01734 | cov=100% ent=100% | 598w/572w | att=1 | bad=1 err=0 | ETA 77m
# [proc  165 | ok 164/444] OK  HA_02911 | cov=100% ent=100% | 1136w/1264w | att=2 | bad=1 err=0 | ETA 77m
# [proc  166 | ok 165/444] OK  HA_03219 | cov=100% ent=100% | 2400w/2939w | att=1 | bad=1 err=0 | ETA 79m
# [proc  167 | ok 166/444] OK  HA_00146 | cov=100% ent=100% | 445w/451w | att=1 | bad=1 err=0 | ETA 78m
# [proc  168 | ok 167/444] OK  HA_01534 | cov=98% ent=96% | 702w/631w | att=1 | bad=1 err=0 | ETA 78m
# [proc  169 | ok 168/444] OK  HA_01986 | cov=100% ent=100% | 596w/576w | att=1 | bad=1 err=0 | ETA 77m
# [proc  170 | ok 169/444] OK  HA_01369 | cov=100% ent=100% | 538w/476w | att=1 | bad=1 err=0 | ETA 77m
#     >>> processed 170 | 169/444 successes | cost so far $1.19
# [proc  171 | ok 170/444] OK  HA_02450 | cov=98% ent=96% | 994w/873w | att=1 | bad=1 err=0 | ETA 76m
# [proc  172 | ok 171/444] OK  HA_03423 | cov=100% ent=100% | 1476w/1562w | att=1 | bad=1 err=0 | ETA 76m
# [proc  173 | ok 172/444] OK  HA_03002 | cov=100% ent=100% | 1593w/1298w | att=1 | bad=1 err=0 | ETA 77m
# [proc  174 | ok 173/444] OK  HA_02811 | cov=97% ent=94% | 1700w/1582w | att=1 | bad=1 err=0 | ETA 77m
# [proc  175 | ok 174/444] OK  HA_00659 | cov=100% ent=100% | 395w/416w | att=1 | bad=1 err=0 | ETA 76m
# [proc  176 | ok 175/444] OK  HA_01794 | cov=100% ent=100% | 636w/563w | att=1 | bad=1 err=0 | ETA 76m
# [proc  177 | ok 176/444] OK  HA_02511 | cov=100% ent=100% | 865w/841w | att=2 | bad=1 err=0 | ETA 76m
# [proc  178 | ok 177/444] OK  HA_00186 | cov=100% ent=100% | 430w/434w | att=1 | bad=1 err=0 | ETA 75m
# [proc  179 | ok 178/444] OK  HA_01147 | cov=100% ent=100% | 480w/480w | att=1 | bad=1 err=0 | ETA 74m
# [proc  180 | ok 179/444] OK  HA_00608 | cov=100% ent=100% | 440w/445w | att=1 | bad=1 err=0 | ETA 74m
#     >>> processed 180 | 179/444 successes | cost so far $1.27
# [proc  181 | ok 180/444] OK  HA_02191 | cov=100% ent=100% | 979w/817w | att=1 | bad=1 err=0 | ETA 74m
# [proc  182 | ok 181/444] OK  HA_02799 | cov=98% ent=96% | 1158w/1315w | att=1 | bad=1 err=0 | ETA 74m
# [proc  183 | ok 182/444] OK  HA_01930 | cov=100% ent=100% | 596w/564w | att=1 | bad=1 err=0 | ETA 73m
# [proc  184 | ok 183/444] OK  HA_03029 | cov=100% ent=100% | 2500w/3380w | att=1 | bad=1 err=0 | ETA 74m
# [proc  185 | ok 184/444] OK  HA_00197 | cov=100% ent=100% | 381w/400w | att=1 | bad=1 err=0 | ETA 73m
# [proc  186 | ok 185/444] OK  HA_02931 | cov=100% ent=100% | 1208w/962w | att=1 | bad=1 err=0 | ETA 74m
# [proc  187 | ok 186/444] OK  HA_02327 | cov=98% ent=96% | 858w/758w | att=1 | bad=1 err=0 | ETA 73m
# [proc  188 | ok 187/444] OK  HA_00293 | cov=97% ent=95% | 384w/415w | att=1 | bad=1 err=0 | ETA 73m
# [proc  189 | ok 188/444] OK  HA_00766 | cov=96% ent=92% | 538w/482w | att=1 | bad=1 err=0 | ETA 72m
# [proc  190 | ok 189/444] OK  HA_00400 | cov=100% ent=100% | 380w/414w | att=1 | bad=1 err=0 | ETA 72m
#     >>> processed 190 | 189/444 successes | cost so far $1.35
# [proc  191 | ok 190/444] OK  HA_00122 | cov=100% ent=100% | 389w/408w | att=1 | bad=1 err=0 | ETA 71m
# [proc  192 | ok 191/444] OK  HA_00202 | cov=100% ent=100% | 400w/417w | att=1 | bad=1 err=0 | ETA 71m
# [proc  193 | ok 192/444] OK  HA_00835 | cov=100% ent=100% | 449w/467w | att=1 | bad=1 err=0 | ETA 70m
# [proc  194 | ok 193/444] OK  HA_02294 | cov=100% ent=100% | 902w/750w | att=1 | bad=1 err=0 | ETA 70m
# [proc  195 | ok 194/444] OK  HA_01439 | cov=100% ent=100% | 586w/570w | att=1 | bad=1 err=0 | ETA 70m
# [proc  196 | ok 195/444] OK  HA_01733 | cov=100% ent=100% | 577w/567w | att=1 | bad=1 err=0 | ETA 70m
# [proc  197 | ok 196/444] OK  HA_01695 | cov=100% ent=100% | 700w/597w | att=1 | bad=1 err=0 | ETA 69m
# [proc  198 | ok 197/444] OK  HA_03414 | cov=100% ent=100% | 1294w/1143w | att=1 | bad=1 err=0 | ETA 69m
# [proc  199 | ok 198/444] OK  HA_01707 | cov=100% ent=100% | 650w/619w | att=1 | bad=1 err=0 | ETA 69m
# [proc  200 | ok 199/444] OK  HA_03398 | cov=100% ent=100% | 902w/933w | att=1 | bad=1 err=0 | ETA 68m
#     >>> processed 200 | 199/444 successes | cost so far $1.41
# [proc  201 | ok 200/444] OK  HA_01153 | cov=100% ent=100% | 545w/526w | att=1 | bad=1 err=0 | ETA 68m
# [proc  202 | ok 201/444] OK  HA_01661 | cov=100% ent=100% | 557w/550w | att=1 | bad=1 err=0 | ETA 67m
# [proc  203 | ok 202/444] OK  HA_02432 | cov=100% ent=100% | 875w/789w | att=1 | bad=1 err=0 | ETA 67m
# [proc  204 | ok 203/444] OK  HA_01759 | cov=100% ent=100% | 841w/629w | att=1 | bad=1 err=0 | ETA 67m
# [proc  205 | ok 204/444] OK  HA_00854 | cov=97% ent=95% | 460w/469w | att=1 | bad=1 err=0 | ETA 67m
# [proc  206 | ok 205/444] OK  HA_01589 | cov=100% ent=100% | 640w/574w | att=1 | bad=1 err=0 | ETA 66m
# [proc  207 | ok 206/444] OK  HA_02267 | cov=98% ent=95% | 933w/851w | att=1 | bad=1 err=0 | ETA 66m
# [proc  208 | ok 207/444] OK  HA_00641 | cov=100% ent=100% | 417w/411w | att=1 | bad=1 err=0 | ETA 65m
# [proc  209 | ok 208/444] OK  HA_00001 | cov=100% ent=100% | 500w/465w | att=1 | bad=1 err=0 | ETA 65m
# [proc  210 | ok 209/444] OK  HA_02160 | cov=100% ent=100% | 809w/699w | att=1 | bad=1 err=0 | ETA 65m
#     >>> processed 210 | 209/444 successes | cost so far $1.46
# [proc  211 | ok 210/444] OK  HA_00698 | cov=100% ent=100% | 401w/430w | att=1 | bad=1 err=0 | ETA 64m
# [proc  212 | ok 211/444] OK  HA_03424 | cov=100% ent=100% | 1462w/1513w | att=1 | bad=1 err=0 | ETA 64m
# [proc  213 | ok 212/444] OK  HA_02999 | cov=100% ent=100% | 872w/937w | att=1 | bad=1 err=0 | ETA 64m
# [proc  214 | ok 213/444] OK  HA_01636 | cov=100% ent=100% | 815w/628w | att=1 | bad=1 err=0 | ETA 64m
# [proc  215 | ok 214/444] OK  HA_03184 | cov=100% ent=100% | 996w/1097w | att=1 | bad=1 err=0 | ETA 63m
# [proc  216 | ok 215/444] OK  HA_01291 | cov=100% ent=100% | 450w/493w | att=1 | bad=1 err=0 | ETA 63m
# [proc  217 | ok 216/444] OK  HA_03331 | cov=100% ent=100% | 1729w/1758w | att=1 | bad=1 err=0 | ETA 63m
# [proc  218 | ok 217/444] OK  HA_02489 | cov=100% ent=100% | 684w/686w | att=1 | bad=1 err=0 | ETA 62m
# [proc  219 | ok 218/444] OK  HA_01520 | cov=100% ent=100% | 542w/568w | att=1 | bad=1 err=0 | ETA 62m
# [proc  220 | ok 219/444] OK  HA_01853 | cov=98% ent=96% | 546w/562w | att=1 | bad=1 err=0 | ETA 62m
#     >>> processed 220 | 219/444 successes | cost so far $1.52
# [proc  221 | ok 220/444] OK  HA_01136 | cov=100% ent=100% | 518w/477w | att=1 | bad=1 err=0 | ETA 61m
# [proc  222 | ok 221/444] OK  HA_03382 | cov=100% ent=100% | 1773w/3763w | att=1 | bad=1 err=0 | ETA 61m
# [proc  223 | ok 222/444] OK  HA_01631 | cov=100% ent=100% | 709w/635w | att=1 | bad=1 err=0 | ETA 61m
# [proc  224 | ok 223/444] OK  HA_01998 | cov=100% ent=100% | 707w/656w | att=1 | bad=1 err=0 | ETA 61m
# [proc  225 | ok 224/444] OK  HA_00663 | cov=100% ent=100% | 399w/404w | att=1 | bad=1 err=0 | ETA 60m
# [proc  226 | ok 225/444] OK  HA_00683 | cov=100% ent=100% | 414w/446w | att=1 | bad=1 err=0 | ETA 60m
# [proc  227 | ok 226/444] OK  HA_01257 | cov=100% ent=100% | 474w/530w | att=1 | bad=1 err=0 | ETA 59m
# [proc  228 | ok 227/444] OK  HA_00317 | cov=93% ent=100% | 385w/403w | att=1 | bad=1 err=0 | ETA 59m
# [proc  229 | ok 228/444] OK  HA_00648 | cov=100% ent=100% | 382w/403w | att=1 | bad=1 err=0 | ETA 59m
# [proc  230 | ok 229/444] OK  HA_01434 | cov=100% ent=100% | 735w/652w | att=1 | bad=1 err=0 | ETA 58m
#     >>> processed 230 | 229/444 successes | cost so far $1.58
# [proc  231 | ok 230/444] OK  HA_01479 | cov=97% ent=95% | 667w/612w | att=1 | bad=1 err=0 | ETA 58m
# [proc  232 | ok 231/444] OK  HA_00709 | cov=100% ent=100% | 550w/515w | att=1 | bad=1 err=0 | ETA 57m
# [proc  233 | ok 232/444] OK  HA_01282 | cov=97% ent=95% | 501w/516w | att=1 | bad=1 err=0 | ETA 57m
# [proc  234 | ok 233/444] OK  HA_01768 | cov=100% ent=100% | 674w/614w | att=1 | bad=1 err=0 | ETA 57m
# [proc  235 | ok 234/444] OK  HA_00972 | cov=100% ent=100% | 542w/494w | att=1 | bad=1 err=0 | ETA 56m
# [proc  236 | ok 235/444] OK  HA_02675 | cov=100% ent=100% | 956w/826w | att=1 | bad=1 err=0 | ETA 56m
# [proc  237 | ok 236/444] OK  HA_02680 | cov=100% ent=100% | 928w/727w | att=1 | bad=1 err=0 | ETA 56m
# [proc  238 | ok 237/444] OK  HA_01306 | cov=98% ent=96% | 469w/493w | att=1 | bad=1 err=0 | ETA 56m
# [proc  239 | ok 238/444] OK  HA_01400 | cov=100% ent=100% | 503w/497w | att=1 | bad=1 err=0 | ETA 55m
# [proc  240 | ok 239/444] OK  HA_01408 | cov=100% ent=100% | 833w/628w | att=1 | bad=1 err=0 | ETA 55m
#     >>> processed 240 | 239/444 successes | cost so far $1.64
# [proc  241 | ok 240/444] OK  HA_03296 | cov=100% ent=100% | 1130w/931w | att=1 | bad=1 err=0 | ETA 55m
# [proc  242 | ok 241/444] OK  HA_02237 | cov=100% ent=100% | 995w/853w | att=1 | bad=1 err=0 | ETA 55m
# [proc  243 | ok 242/444] OK  HA_01496 | cov=100% ent=100% | 604w/567w | att=1 | bad=1 err=0 | ETA 55m
# [proc  244 | ok 243/444] OK  HA_02038 | cov=98% ent=96% | 536w/548w | att=1 | bad=1 err=0 | ETA 54m
# [proc  245 | ok 244/444] OK  HA_01529 | cov=100% ent=100% | 648w/607w | att=1 | bad=1 err=0 | ETA 54m
# [proc  246 | ok 245/444] OK  HA_01663 | cov=100% ent=100% | 583w/566w | att=1 | bad=1 err=0 | ETA 54m
# [proc  247 | ok 246/444] OK  HA_01354 | cov=100% ent=100% | 557w/528w | att=1 | bad=1 err=0 | ETA 53m
# [proc  248 | ok 247/444] OK  HA_03410 | cov=100% ent=100% | 1374w/1548w | att=1 | bad=1 err=0 | ETA 53m
# [proc  249 | ok 248/444] OK  HA_03433 | cov=100% ent=100% | 1691w/1866w | att=1 | bad=1 err=0 | ETA 53m
# [proc  250 | ok 249/444] OK  HA_01643 | cov=100% ent=100% | 688w/639w | att=1 | bad=1 err=0 | ETA 53m
#     >>> processed 250 | 249/444 successes | cost so far $1.71
# [proc  251 | ok 250/444] OK  HA_01051 | cov=100% ent=100% | 513w/492w | att=1 | bad=1 err=0 | ETA 52m
# [proc  252 | ok 251/444] OK  HA_00795 | cov=100% ent=100% | 475w/478w | att=1 | bad=1 err=0 | ETA 52m
# [proc  253 | ok 252/444] OK  HA_02693 | cov=100% ent=100% | 893w/695w | att=1 | bad=1 err=0 | ETA 52m
# [proc  254 | ok 253/444] OK  HA_03060 | cov=100% ent=100% | 1761w/1422w | att=1 | bad=1 err=0 | ETA 52m
# [proc  255 | ok 254/444] OK  HA_01597 | cov=100% ent=100% | 724w/640w | att=1 | bad=1 err=0 | ETA 51m
# [proc  256 | ok 255/444] OK  HA_02604 | cov=100% ent=100% | 792w/676w | att=1 | bad=1 err=0 | ETA 51m
# [proc  257 | ok 256/444] OK  HA_02729 | cov=100% ent=100% | 939w/857w | att=1 | bad=1 err=0 | ETA 51m
# [proc  258 | ok 257/444] OK  HA_02625 | cov=100% ent=100% | 919w/682w | att=1 | bad=1 err=0 | ETA 51m
# [proc  259 | ok 258/444] OK  HA_01819 | cov=100% ent=100% | 556w/561w | att=1 | bad=1 err=0 | ETA 50m
# [proc  260 | ok 259/444] OK  HA_03157 | cov=100% ent=100% | 1146w/1061w | att=1 | bad=1 err=0 | ETA 50m
#     >>> processed 260 | 259/444 successes | cost so far $1.79
# [proc  261 | ok 260/444] OK  HA_03314 | cov=100% ent=100% | 1089w/1084w | att=1 | bad=1 err=0 | ETA 50m
# [proc  262 | ok 261/444] OK  HA_01722 | cov=100% ent=100% | 643w/594w | att=1 | bad=1 err=0 | ETA 50m
# [proc  263 | ok 262/444] OK  HA_01183 | cov=100% ent=100% | 488w/497w | att=1 | bad=1 err=0 | ETA 49m
# [proc  264 | ok 263/444] OK  HA_02572 | cov=98% ent=96% | 1007w/741w | att=1 | bad=1 err=0 | ETA 49m
# [proc  265 | ok 264/444] OK  HA_01059 | cov=100% ent=100% | 528w/509w | att=1 | bad=1 err=0 | ETA 49m
# [proc  266 | ok 265/444] OK  HA_00540 | cov=100% ent=100% | 389w/425w | att=1 | bad=1 err=0 | ETA 48m
# [proc  267 | ok 266/444] OK  HA_03242 | cov=100% ent=100% | 1102w/935w | att=1 | bad=1 err=0 | ETA 48m
# [proc  268 | ok 267/444] OK  HA_01678 | cov=100% ent=100% | 739w/574w | att=1 | bad=1 err=0 | ETA 48m
# [proc  269 | ok 268/444] OK  HA_02796 | cov=97% ent=93% | 761w/859w | att=1 | bad=1 err=0 | ETA 48m
# [proc  270 | ok 269/444] OK  HA_03371 | cov=100% ent=100% | 1349w/1053w | att=1 | bad=1 err=0 | ETA 48m
#     >>> processed 270 | 269/444 successes | cost so far $1.86
# [proc  271 | ok 270/444] OK  HA_02532 | cov=100% ent=100% | 793w/729w | att=1 | bad=1 err=0 | ETA 47m
# [proc  272 | ok 270/444] BAD HA_01757 | cov=68% ent=91% | 667w/580w | att=1 | bad=2 err=0 | ETA 48m
# [proc  273 | ok 271/444] OK  HA_01923 | cov=100% ent=100% | 569w/576w | att=1 | bad=2 err=0 | ETA 47m
# [proc  274 | ok 272/444] OK  HA_00095 | cov=93% ent=86% | 441w/440w | att=1 | bad=2 err=0 | ETA 47m
# [proc  275 | ok 273/444] OK  HA_01020 | cov=98% ent=96% | 493w/515w | att=1 | bad=2 err=0 | ETA 46m
# [proc  276 | ok 274/444] OK  HA_00563 | cov=100% ent=100% | 382w/429w | att=1 | bad=2 err=0 | ETA 46m
# [proc  277 | ok 275/444] OK  HA_03312 | cov=100% ent=100% | 2124w/3375w | att=1 | bad=2 err=0 | ETA 46m
# [proc  278 | ok 276/444] OK  HA_02790 | cov=100% ent=100% | 812w/747w | att=1 | bad=2 err=0 | ETA 46m
# [proc  279 | ok 277/444] OK  HA_00863 | cov=100% ent=100% | 515w/522w | att=1 | bad=2 err=0 | ETA 46m
# [proc  280 | ok 278/444] OK  HA_01484 | cov=100% ent=100% | 612w/569w | att=1 | bad=2 err=0 | ETA 45m
#     >>> processed 280 | 278/444 successes | cost so far $1.93
# [proc  281 | ok 279/444] OK  HA_02939 | cov=100% ent=100% | 1278w/1337w | att=1 | bad=2 err=0 | ETA 45m
# [proc  282 | ok 280/444] OK  HA_01881 | cov=100% ent=100% | 627w/549w | att=1 | bad=2 err=0 | ETA 45m
# [proc  283 | ok 281/444] OK  HA_01038 | cov=98% ent=96% | 488w/477w | att=1 | bad=2 err=0 | ETA 44m
# [proc  284 | ok 282/444] OK  HA_00206 | cov=90% ent=84% | 394w/435w | att=1 | bad=2 err=0 | ETA 44m
# [proc  285 | ok 283/444] OK  HA_00392 | cov=100% ent=100% | 420w/408w | att=1 | bad=2 err=0 | ETA 44m
# [proc  286 | ok 284/444] OK  HA_02842 | cov=100% ent=100% | 1143w/984w | att=1 | bad=2 err=0 | ETA 44m
# [proc  287 | ok 285/444] OK  HA_00870 | cov=100% ent=100% | 518w/498w | att=1 | bad=2 err=0 | ETA 43m
# [proc  288 | ok 286/444] OK  HA_00397 | cov=100% ent=100% | 412w/448w | att=1 | bad=2 err=0 | ETA 43m
# [proc  289 | ok 287/444] OK  HA_02814 | cov=100% ent=100% | 1014w/936w | att=1 | bad=2 err=0 | ETA 43m
# [proc  290 | ok 288/444] OK  HA_03360 | cov=100% ent=100% | 1143w/947w | att=1 | bad=2 err=0 | ETA 43m
#     >>> processed 290 | 288/444 successes | cost so far $2.00
# [proc  291 | ok 289/444] OK  HA_03289 | cov=100% ent=100% | 1151w/1176w | att=1 | bad=2 err=0 | ETA 42m
# [proc  292 | ok 290/444] OK  HA_01028 | cov=100% ent=100% | 443w/488w | att=1 | bad=2 err=0 | ETA 42m
# [proc  293 | ok 291/444] OK  HA_02690 | cov=100% ent=100% | 660w/673w | att=1 | bad=2 err=0 | ETA 42m
# [proc  294 | ok 292/444] OK  HA_01485 | cov=96% ent=92% | 547w/562w | att=1 | bad=2 err=0 | ETA 41m
# [proc  295 | ok 293/444] OK  HA_02660 | cov=100% ent=100% | 867w/807w | att=1 | bad=2 err=0 | ETA 41m
# [proc  296 | ok 294/444] OK  HA_00960 | cov=100% ent=100% | 507w/535w | att=1 | bad=2 err=0 | ETA 41m
# [proc  297 | ok 295/444] OK  HA_01570 | cov=100% ent=100% | 563w/580w | att=2 | bad=2 err=0 | ETA 40m
# [proc  298 | ok 296/444] OK  HA_02773 | cov=100% ent=100% | 803w/769w | att=1 | bad=2 err=0 | ETA 40m
# [proc  299 | ok 297/444] OK  HA_01895 | cov=94% ent=100% | 719w/640w | att=1 | bad=2 err=0 | ETA 40m
# [proc  300 | ok 298/444] OK  HA_02731 | cov=100% ent=100% | 764w/706w | att=1 | bad=2 err=0 | ETA 39m
#     >>> processed 300 | 298/444 successes | cost so far $2.05
# [proc  301 | ok 299/444] OK  HA_02146 | cov=100% ent=100% | 736w/677w | att=1 | bad=2 err=0 | ETA 39m
# [proc  302 | ok 300/444] OK  HA_00804 | cov=100% ent=100% | 515w/540w | att=1 | bad=2 err=0 | ETA 39m
# [proc  303 | ok 301/444] OK  HA_01751 | cov=100% ent=100% | 600w/592w | att=1 | bad=2 err=0 | ETA 38m
# [proc  304 | ok 302/444] OK  HA_02454 | cov=100% ent=100% | 918w/757w | att=1 | bad=2 err=0 | ETA 38m
# [proc  305 | ok 303/444] OK  HA_00502 | cov=100% ent=100% | 381w/411w | att=1 | bad=2 err=0 | ETA 38m
# [proc  306 | ok 304/444] OK  HA_03119 | cov=98% ent=97% | 3407w/3776w | att=1 | bad=2 err=0 | ETA 38m
# [proc  307 | ok 305/444] OK  HA_03104 | cov=100% ent=100% | 1903w/1999w | att=1 | bad=2 err=0 | ETA 38m
# [proc  308 | ok 306/444] OK  HA_02977 | cov=100% ent=100% | 2865w/3144w | att=1 | bad=2 err=0 | ETA 38m
# [proc  309 | ok 307/444] OK  HA_00779 | cov=100% ent=100% | 477w/513w | att=1 | bad=2 err=0 | ETA 37m
# [proc  310 | ok 308/444] OK  HA_01863 | cov=100% ent=100% | 650w/575w | att=1 | bad=2 err=0 | ETA 37m
#     >>> processed 310 | 308/444 successes | cost so far $2.13
# [proc  311 | ok 309/444] OK  HA_00200 | cov=100% ent=100% | 427w/447w | att=1 | bad=2 err=0 | ETA 37m
# [proc  312 | ok 310/444] OK  HA_02182 | cov=100% ent=100% | 781w/811w | att=1 | bad=2 err=0 | ETA 36m
# [proc  313 | ok 311/444] OK  HA_03099 | cov=100% ent=100% | 2082w/2407w | att=1 | bad=2 err=0 | ETA 36m
# [proc  314 | ok 312/444] OK  HA_02088 | cov=100% ent=100% | 554w/590w | att=1 | bad=2 err=0 | ETA 36m
# [proc  315 | ok 313/444] OK  HA_03065 | cov=100% ent=100% | 1719w/1447w | att=1 | bad=2 err=0 | ETA 36m
# [proc  316 | ok 314/444] OK  HA_02278 | cov=100% ent=100% | 839w/713w | att=1 | bad=2 err=0 | ETA 36m
# [proc  317 | ok 315/444] OK  HA_01796 | cov=100% ent=100% | 627w/569w | att=1 | bad=2 err=0 | ETA 35m
# [proc  318 | ok 316/444] OK  HA_00378 | cov=100% ent=100% | 444w/438w | att=1 | bad=2 err=0 | ETA 35m
# [proc  319 | ok 317/444] OK  HA_02336 | cov=100% ent=100% | 842w/845w | att=1 | bad=2 err=0 | ETA 35m
# [proc  320 | ok 318/444] OK  HA_00418 | cov=100% ent=100% | 416w/432w | att=1 | bad=2 err=0 | ETA 34m
#     >>> processed 320 | 318/444 successes | cost so far $2.20
# [proc  321 | ok 319/444] OK  HA_01698 | cov=100% ent=100% | 776w/618w | att=1 | bad=2 err=0 | ETA 34m
# [proc  322 | ok 320/444] OK  HA_00391 | cov=100% ent=100% | 408w/440w | att=1 | bad=2 err=0 | ETA 34m
# [proc  323 | ok 321/444] OK  HA_02640 | cov=100% ent=100% | 933w/717w | att=1 | bad=2 err=0 | ETA 34m
# [proc  324 | ok 322/444] OK  HA_01522 | cov=100% ent=100% | 893w/647w | att=1 | bad=2 err=0 | ETA 33m
# [proc  325 | ok 323/444] OK  HA_01162 | cov=100% ent=100% | 494w/500w | att=1 | bad=2 err=0 | ETA 33m
# [proc  326 | ok 323/444] BAD HA_03134 | cov=67% ent=100% | 1070w/1032w | att=1 | bad=3 err=0 | ETA 33m
# [proc  327 | ok 324/444] OK  HA_01495 | cov=100% ent=100% | 522w/562w | att=1 | bad=3 err=0 | ETA 33m
# [proc  328 | ok 325/444] OK  HA_02695 | cov=100% ent=100% | 706w/682w | att=1 | bad=3 err=0 | ETA 33m
# [proc  329 | ok 326/444] OK  HA_02027 | cov=100% ent=100% | 681w/636w | att=1 | bad=3 err=0 | ETA 32m
# [proc  330 | ok 327/444] OK  HA_01152 | cov=100% ent=100% | 535w/507w | att=1 | bad=3 err=0 | ETA 32m
#     >>> processed 330 | 327/444 successes | cost so far $2.27
# [proc  331 | ok 328/444] OK  HA_01367 | cov=98% ent=96% | 529w/492w | att=1 | bad=3 err=0 | ETA 32m
# [proc  332 | ok 329/444] OK  HA_02568 | cov=100% ent=100% | 814w/798w | att=1 | bad=3 err=0 | ETA 31m
# [proc  333 | ok 330/444] OK  HA_00064 | cov=100% ent=100% | 399w/430w | att=1 | bad=3 err=0 | ETA 31m
# [proc  334 | ok 331/444] OK  HA_02062 | cov=100% ent=100% | 669w/579w | att=1 | bad=3 err=0 | ETA 31m
# [proc  335 | ok 332/444] OK  HA_01180 | cov=95% ent=94% | 517w/533w | att=1 | bad=3 err=0 | ETA 30m
# [proc  336 | ok 333/444] OK  HA_03112 | cov=100% ent=100% | 1619w/1317w | att=1 | bad=3 err=0 | ETA 30m
# [proc  337 | ok 334/444] OK  HA_00492 | cov=100% ent=100% | 436w/434w | att=1 | bad=3 err=0 | ETA 30m
# [proc  338 | ok 335/444] OK  HA_00379 | cov=98% ent=95% | 425w/466w | att=1 | bad=3 err=0 | ETA 30m
# [proc  339 | ok 336/444] OK  HA_02235 | cov=100% ent=100% | 1036w/778w | att=1 | bad=3 err=0 | ETA 29m
# [proc  340 | ok 337/444] OK  HA_00763 | cov=100% ent=100% | 490w/487w | att=1 | bad=3 err=0 | ETA 29m
#     >>> processed 340 | 337/444 successes | cost so far $2.34
# [proc  341 | ok 338/444] OK  HA_02264 | cov=97% ent=96% | 830w/813w | att=1 | bad=3 err=0 | ETA 29m
# [proc  342 | ok 339/444] OK  HA_00791 | cov=100% ent=100% | 503w/482w | att=1 | bad=3 err=0 | ETA 29m
# [proc  343 | ok 340/444] OK  HA_01076 | cov=100% ent=100% | 590w/539w | att=1 | bad=3 err=0 | ETA 28m
# [proc  344 | ok 341/444] OK  HA_00878 | cov=100% ent=100% | 486w/483w | att=1 | bad=3 err=0 | ETA 28m
# [proc  345 | ok 342/444] OK  HA_00337 | cov=100% ent=100% | 464w/449w | att=1 | bad=3 err=0 | ETA 28m
# [proc  346 | ok 343/444] OK  HA_02767 | cov=100% ent=100% | 797w/697w | att=1 | bad=3 err=0 | ETA 27m
# [proc  347 | ok 344/444] OK  HA_02343 | cov=100% ent=100% | 799w/666w | att=1 | bad=3 err=0 | ETA 27m
# [proc  348 | ok 345/444] OK  HA_01016 | cov=100% ent=100% | 468w/488w | att=1 | bad=3 err=0 | ETA 27m
# [proc  349 | ok 346/444] OK  HA_01275 | cov=100% ent=100% | 473w/484w | att=1 | bad=3 err=0 | ETA 26m
# [proc  350 | ok 347/444] OK  HA_00455 | cov=100% ent=100% | 393w/406w | att=1 | bad=3 err=0 | ETA 26m
#     >>> processed 350 | 347/444 successes | cost so far $2.38
# [proc  351 | ok 348/444] OK  HA_03342 | cov=100% ent=100% | 1246w/1184w | att=1 | bad=3 err=0 | ETA 26m
# [proc  352 | ok 349/444] OK  HA_00815 | cov=100% ent=100% | 468w/485w | att=1 | bad=3 err=0 | ETA 26m
# [proc  353 | ok 350/444] OK  HA_02317 | cov=100% ent=100% | 838w/739w | att=1 | bad=3 err=0 | ETA 25m
# [proc  354 | ok 351/444] OK  HA_00995 | cov=100% ent=100% | 571w/523w | att=1 | bad=3 err=0 | ETA 25m
# [proc  355 | ok 352/444] OK  HA_01981 | cov=100% ent=100% | 669w/618w | att=1 | bad=3 err=0 | ETA 25m
# [proc  356 | ok 353/444] OK  HA_00201 | cov=98% ent=96% | 369w/401w | att=1 | bad=3 err=0 | ETA 24m
# [proc  357 | ok 354/444] OK  HA_00161 | cov=100% ent=100% | 418w/443w | att=1 | bad=3 err=0 | ETA 24m
# [proc  358 | ok 355/444] OK  HA_01579 | cov=100% ent=100% | 648w/647w | att=1 | bad=3 err=0 | ETA 24m
# [proc  359 | ok 356/444] OK  HA_02777 | cov=100% ent=100% | 998w/855w | att=1 | bad=3 err=0 | ETA 24m
# [proc  360 | ok 357/444] OK  HA_02449 | cov=100% ent=100% | 765w/714w | att=1 | bad=3 err=0 | ETA 23m
#     >>> processed 360 | 357/444 successes | cost so far $2.43
# [proc  361 | ok 358/444] OK  HA_00702 | cov=100% ent=100% | 508w/538w | att=1 | bad=3 err=0 | ETA 23m
# [proc  362 | ok 359/444] OK  HA_01500 | cov=100% ent=100% | 698w/653w | att=1 | bad=3 err=0 | ETA 23m
# [proc  363 | ok 360/444] OK  HA_01129 | cov=100% ent=100% | 481w/503w | att=1 | bad=3 err=0 | ETA 22m
# [proc  364 | ok 361/444] OK  HA_02613 | cov=100% ent=100% | 895w/729w | att=1 | bad=3 err=0 | ETA 22m
# [proc  365 | ok 362/444] OK  HA_01021 | cov=100% ent=100% | 495w/472w | att=1 | bad=3 err=0 | ETA 22m
# [proc  366 | ok 363/444] OK  HA_03073 | cov=100% ent=100% | 1164w/1088w | att=1 | bad=3 err=0 | ETA 22m
# [proc  367 | ok 364/444] OK  HA_01585 | cov=100% ent=100% | 771w/634w | att=2 | bad=3 err=0 | ETA 21m
# [proc  368 | ok 365/444] OK  HA_01955 | cov=100% ent=100% | 632w/595w | att=1 | bad=3 err=0 | ETA 21m
# [proc  369 | ok 366/444] OK  HA_03152 | cov=100% ent=100% | 1409w/1086w | att=1 | bad=3 err=0 | ETA 21m
# [proc  370 | ok 367/444] OK  HA_02253 | cov=100% ent=100% | 709w/663w | att=1 | bad=3 err=0 | ETA 21m
#     >>> processed 370 | 367/444 successes | cost so far $2.50
# [proc  371 | ok 368/444] OK  HA_00034 | cov=98% ent=96% | 457w/465w | att=1 | bad=3 err=0 | ETA 20m
# [proc  372 | ok 369/444] OK  HA_00775 | cov=93% ent=100% | 503w/540w | att=1 | bad=3 err=0 | ETA 20m
# [proc  373 | ok 370/444] OK  HA_02556 | cov=100% ent=100% | 849w/731w | att=1 | bad=3 err=0 | ETA 20m
# [proc  374 | ok 371/444] OK  HA_01478 | cov=100% ent=100% | 560w/544w | att=1 | bad=3 err=0 | ETA 19m
# [proc  375 | ok 372/444] OK  HA_03003 | cov=98% ent=96% | 1579w/1442w | att=1 | bad=3 err=0 | ETA 19m
# [proc  376 | ok 373/444] OK  HA_01390 | cov=100% ent=100% | 506w/502w | att=1 | bad=3 err=0 | ETA 19m
# [proc  377 | ok 374/444] OK  HA_02139 | cov=100% ent=100% | 920w/875w | att=1 | bad=3 err=0 | ETA 19m
# [proc  378 | ok 375/444] OK  HA_01363 | cov=100% ent=100% | 496w/495w | att=1 | bad=3 err=0 | ETA 18m
# [proc  379 | ok 376/444] OK  HA_02945 | cov=100% ent=100% | 1200w/1080w | att=1 | bad=3 err=0 | ETA 18m
# [proc  380 | ok 377/444] OK  HA_02612 | cov=100% ent=100% | 826w/754w | att=1 | bad=3 err=0 | ETA 18m
#     >>> processed 380 | 377/444 successes | cost so far $2.55
# [proc  381 | ok 378/444] OK  HA_03417 | cov=100% ent=100% | 890w/975w | att=1 | bad=3 err=0 | ETA 18m
# [proc  382 | ok 379/444] OK  HA_02824 | cov=83% ent=100% | 2137w/2192w | att=1 | bad=3 err=0 | ETA 17m
# [proc  383 | ok 380/444] OK  HA_02041 | cov=97% ent=94% | 694w/652w | att=1 | bad=3 err=0 | ETA 17m
# [proc  384 | ok 381/444] OK  HA_00241 | cov=100% ent=100% | 390w/438w | att=1 | bad=3 err=0 | ETA 17m
# [proc  385 | ok 382/444] OK  HA_02061 | cov=100% ent=100% | 702w/655w | att=1 | bad=3 err=0 | ETA 17m
# [proc  386 | ok 383/444] OK  HA_02363 | cov=98% ent=95% | 846w/862w | att=1 | bad=3 err=0 | ETA 16m
# [proc  387 | ok 384/444] OK  HA_00600 | cov=100% ent=100% | 394w/406w | att=1 | bad=3 err=0 | ETA 16m
# [proc  388 | ok 385/444] OK  HA_02435 | cov=100% ent=100% | 758w/708w | att=1 | bad=3 err=0 | ETA 16m
# [proc  389 | ok 386/444] OK  HA_01297 | cov=100% ent=100% | 509w/488w | att=1 | bad=3 err=0 | ETA 15m
# [proc  390 | ok 387/444] OK  HA_02214 | cov=80% ent=100% | 930w/824w | att=1 | bad=3 err=0 | ETA 15m
#     >>> processed 390 | 387/444 successes | cost so far $2.61
# [proc  391 | ok 388/444] OK  HA_02888 | cov=100% ent=100% | 1450w/1249w | att=1 | bad=3 err=0 | ETA 15m
# [proc  392 | ok 389/444] OK  HA_02068 | cov=100% ent=100% | 596w/556w | att=1 | bad=3 err=0 | ETA 15m
# [proc  393 | ok 390/444] OK  HA_00646 | cov=100% ent=100% | 419w/418w | att=1 | bad=3 err=0 | ETA 14m
# [proc  394 | ok 391/444] OK  HA_03202 | cov=100% ent=100% | 1588w/1622w | att=1 | bad=3 err=0 | ETA 14m
# [proc  395 | ok 392/444] OK  HA_01528 | cov=100% ent=100% | 706w/610w | att=1 | bad=3 err=0 | ETA 14m
# [proc  396 | ok 393/444] OK  HA_02879 | cov=98% ent=96% | 999w/947w | att=1 | bad=3 err=0 | ETA 14m
# [proc  397 | ok 394/444] OK  HA_01267 | cov=95% ent=93% | 466w/493w | att=1 | bad=3 err=0 | ETA 13m
# [proc  398 | ok 395/444] OK  HA_01899 | cov=100% ent=100% | 720w/615w | att=1 | bad=3 err=0 | ETA 13m
# [proc  399 | ok 396/444] OK  HA_00562 | cov=100% ent=100% | 417w/438w | att=1 | bad=3 err=0 | ETA 13m
# [proc  400 | ok 397/444] OK  HA_03457 | cov=100% ent=100% | 1557w/1403w | att=1 | bad=3 err=0 | ETA 12m
#     >>> processed 400 | 397/444 successes | cost so far $2.68
# [proc  401 | ok 398/444] OK  HA_02734 | cov=100% ent=100% | 738w/676w | att=1 | bad=3 err=0 | ETA 12m
# [proc  402 | ok 399/444] OK  HA_03005 | cov=100% ent=100% | 2397w/2435w | att=1 | bad=3 err=0 | ETA 12m
# [proc  403 | ok 400/444] OK  HA_00189 | cov=100% ent=100% | 432w/423w | att=1 | bad=3 err=0 | ETA 12m
# [proc  404 | ok 401/444] OK  HA_01806 | cov=100% ent=100% | 614w/549w | att=1 | bad=3 err=0 | ETA 11m
# [proc  405 | ok 402/444] OK  HA_00975 | cov=100% ent=100% | 562w/527w | att=1 | bad=3 err=0 | ETA 11m
# [proc  406 | ok 403/444] OK  HA_02747 | cov=100% ent=100% | 976w/819w | att=1 | bad=3 err=0 | ETA 11m
# [proc  407 | ok 404/444] OK  HA_02047 | cov=98% ent=97% | 624w/625w | att=1 | bad=3 err=0 | ETA 11m
# [proc  408 | ok 405/444] OK  HA_02558 | cov=95% ent=92% | 999w/866w | att=1 | bad=3 err=0 | ETA 10m
# [proc  409 | ok 406/444] OK  HA_01082 | cov=100% ent=100% | 528w/510w | att=1 | bad=3 err=0 | ETA 10m
# [proc  410 | ok 407/444] OK  HA_00474 | cov=98% ent=96% | 464w/465w | att=1 | bad=3 err=0 | ETA 10m
#     >>> processed 410 | 407/444 successes | cost so far $2.75
# [proc  411 | ok 408/444] OK  HA_02904 | cov=100% ent=100% | 1109w/906w | att=1 | bad=3 err=0 | ETA 10m
# [proc  412 | ok 409/444] OK  HA_00747 | cov=100% ent=100% | 463w/492w | att=1 | bad=3 err=0 | ETA 9m
# [proc  413 | ok 410/444] OK  HA_02300 | cov=100% ent=100% | 849w/723w | att=1 | bad=3 err=0 | ETA 9m
# [proc  414 | ok 411/444] OK  HA_00021 | cov=100% ent=100% | 392w/408w | att=1 | bad=3 err=0 | ETA 9m
# [proc  415 | ok 412/444] OK  HA_03385 | cov=100% ent=100% | 1074w/1026w | att=1 | bad=3 err=0 | ETA 9m
# [proc  416 | ok 413/444] OK  HA_00459 | cov=100% ent=100% | 425w/448w | att=1 | bad=3 err=0 | ETA 8m
# [proc  417 | ok 414/444] OK  HA_01184 | cov=100% ent=100% | 467w/515w | att=1 | bad=3 err=0 | ETA 8m
# [proc  418 | ok 415/444] OK  HA_02324 | cov=100% ent=100% | 886w/721w | att=1 | bad=3 err=0 | ETA 8m
# [proc  419 | ok 416/444] OK  HA_00955 | cov=100% ent=100% | 537w/540w | att=1 | bad=3 err=0 | ETA 7m
# [proc  420 | ok 417/444] OK  HA_01215 | cov=100% ent=100% | 636w/539w | att=1 | bad=3 err=0 | ETA 7m
#     >>> processed 420 | 417/444 successes | cost so far $2.81
# [proc  421 | ok 418/444] OK  HA_02433 | cov=100% ent=100% | 724w/753w | att=1 | bad=3 err=0 | ETA 7m
# [proc  422 | ok 419/444] OK  HA_02853 | cov=100% ent=100% | 1061w/1003w | att=1 | bad=3 err=0 | ETA 7m
# [proc  423 | ok 420/444] OK  HA_01515 | cov=88% ent=100% | 646w/627w | att=1 | bad=3 err=0 | ETA 6m
# [proc  424 | ok 421/444] OK  HA_02391 | cov=100% ent=100% | 762w/737w | att=1 | bad=3 err=0 | ETA 6m
# [proc  425 | ok 422/444] OK  HA_00769 | cov=100% ent=100% | 435w/473w | att=1 | bad=3 err=0 | ETA 6m
# [proc  426 | ok 423/444] OK  HA_03380 | cov=94% ent=100% | 2591w/2591w | att=1 | bad=3 err=0 | ETA 6m
# [proc  427 | ok 424/444] OK  HA_01685 | cov=100% ent=100% | 677w/594w | att=1 | bad=3 err=0 | ETA 5m
# [proc  428 | ok 425/444] OK  HA_00130 | cov=97% ent=95% | 466w/454w | att=1 | bad=3 err=0 | ETA 5m
# [proc  429 | ok 426/444] OK  HA_02919 | cov=100% ent=100% | 1138w/969w | att=1 | bad=3 err=0 | ETA 5m
# [proc  430 | ok 427/444] OK  HA_03171 | cov=100% ent=100% | 1729w/1309w | att=1 | bad=3 err=0 | ETA 5m
#     >>> processed 430 | 427/444 successes | cost so far $2.90
# [proc  431 | ok 428/444] OK  HA_03444 | cov=100% ent=100% | 1570w/1722w | att=1 | bad=3 err=0 | ETA 4m
# [proc  432 | ok 429/444] OK  HA_02135 | cov=100% ent=100% | 737w/691w | att=1 | bad=3 err=0 | ETA 4m
# [proc  433 | ok 430/444] OK  HA_01482 | cov=93% ent=100% | 622w/571w | att=1 | bad=3 err=0 | ETA 4m
# [proc  434 | ok 431/444] OK  HA_00330 | cov=97% ent=95% | 438w/441w | att=1 | bad=3 err=0 | ETA 3m
# [proc  435 | ok 432/444] OK  HA_01238 | cov=83% ent=100% | 488w/487w | att=1 | bad=3 err=0 | ETA 3m
# [proc  436 | ok 433/444] OK  HA_00466 | cov=100% ent=100% | 428w/443w | att=1 | bad=3 err=0 | ETA 3m
# [proc  437 | ok 434/444] OK  HA_02169 | cov=93% ent=97% | 851w/822w | att=1 | bad=3 err=0 | ETA 3m
# [proc  438 | ok 435/444] OK  HA_01638 | cov=100% ent=100% | 684w/631w | att=1 | bad=3 err=0 | ETA 2m
# [proc  439 | ok 436/444] OK  HA_03092 | cov=100% ent=100% | 1038w/1026w | att=1 | bad=3 err=0 | ETA 2m
# [proc  440 | ok 437/444] OK  HA_01095 | cov=100% ent=100% | 560w/523w | att=1 | bad=3 err=0 | ETA 2m
#     >>> processed 440 | 437/444 successes | cost so far $2.94
# [proc  441 | ok 438/444] OK  HA_01130 | cov=100% ent=100% | 524w/480w | att=1 | bad=3 err=0 | ETA 2m
# [proc  442 | ok 439/444] OK  HA_01294 | cov=100% ent=100% | 493w/525w | att=1 | bad=3 err=0 | ETA 1m
# [proc  443 | ok 440/444] OK  HA_00860 | cov=100% ent=100% | 520w/493w | att=1 | bad=3 err=0 | ETA 1m
# [proc  444 | ok 441/444] OK  HA_03174 | cov=100% ent=100% | 1157w/1190w | att=1 | bad=3 err=0 | ETA 1m
#
# !! WORK LIST EXHAUSTED before quota: 441/444. Need more cards.
#
# DONE gemini | successes=441/444 | rejects=3 err=0 | processed=444 | total cost $2.96

# %%
# final verification (production only)
if not PILOT_ONLY:
    final = pd.read_parquet(CKPT)
    n_pass = int(final['gate_passed'].sum())
    n_fail = int((~final['gate_passed']).sum())
    print('processed    :', len(final), '| unique ids:', final['source_pair_id'].nunique())
    print('SUCCESSES    :', n_pass, f'(quota was {QUOTA})')
    print('rejects      :', n_fail, '(these carry over to the next generator)')
    print('errors       :', int((final['error'] != '').sum()))
    print('length ok    :', int(final['length_ok'].sum()), f"({100*final['length_ok'].mean():.0f}%)")
    print('mean coverage:', f"{final['coverage_weighted'].mean():.0%}")
    print('mean attempts:', f"{final['generation_attempts'].mean():.2f}")
    n_md = int(final['text'].str.contains('**', regex=False).sum())
    n_nl = int(final['text'].str.contains(chr(10), regex=False).sum())
    print('markdown/newlines left:', n_md, '/', n_nl, '(must be 0)')
    print(f'\nquota met: {n_pass >= QUOTA}  |  upload as aigt-aig-qwen for the next generator')
# Out:
# processed    : 444 | unique ids: 444
# SUCCESSES    : 441 (quota was 444)
# rejects      : 3 (these carry over to the next generator)
# errors       : 0
# length ok    : 362 (82%)
# mean coverage: 99%
# mean attempts: 1.02
# markdown/newlines left: 0 / 0 (must be 0)
#
# quota met: False  |  upload as aigt-aig-qwen for the next generator

# %% [markdown]
# ## Notes
#
# - **This notebook closes the corpus.** 444 cards left, 444 successes needed — arithmetically
#   impossible in one pass at any realistic gate rate, so ~22 rejects are expected and a small salvage
#   round (same notebook, `PRIOR_OUTPUTS` extended with this output) finishes them off.
# - **Efficiency tier, third time.** Sonnet beat Opus 34-vs-90 rejects; GPT-5 Mini then posted the
#   best pass rate of any generator at 95.4%. The stronger model paraphrases figures; the efficient
#   one carries them. That's the property counter-generation actually needs.
# - **Reasoning resolves itself.** The smoke test settles `enabled: false` vs `effort: low` in one
#   call instead of one run — the lesson GPT-5 Mini taught me.
# - **Synchronous beats Batch here.** OpenRouter has no batch endpoint, which hands back the
#   regenerate loop: measured per-card pass rates were 97.6% (DeepSeek), 97.6% (Qwen) and 95.4% (GPT)
#   with the loop, against 92.8% (Sonnet) and 80.9% (Opus) through Batch without it. The loop is worth
#   more than Batch's 50% discount at these prices.
# - **Number emphasis stays.** "احرص على ذكر ... كما هي" lifted Qwen 76% -> 93% and salvaged 75% of
#   Sonnet/Opus rejects that were sitting at 0%. It's factual fidelity — making the article carry its
#   card's facts — not tuning against any of my five detection features.
# - **Budget:** GPT cost $2.40 of the ~$14 set aside. Gemini at $0.50/$3 should land near $4-5, so the
#   salvage round is comfortably covered.
# - **Merge (NB2j):** concatenate all outputs, keep one row per `source_pair_id`, preferring
#   `gate_passed=True`. 104 cards currently carry two passing articles — an artifact of Sonnet/Opus
#   reading a stale Qwen dataset — which also means I get to choose which generator represents them,
#   a small lever for balancing the generator mix.
